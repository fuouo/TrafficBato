# %%
import numpy as np
import pandas as pd

# %%
# Read the dataset
ROAD = "Quirino"
YEAR = "2015"
EXT = ".csv"
TRANSFORMED = False

#TYPE = "mmda" 
TYPE = "wwo"

WINDOW_START = 2
WINDOW_END = 10

# %% [markdown]
# ### Don't touch beyond this point :)

# %%
for i in range(WINDOW_START, WINDOW_END):
    WEATHER_WINDOWSIZE = i
    #engineered_noeng_wwo_Taft-Ave._2015
    WEATHER_FILENAME = "interpolated_flood_pagasa_" + YEAR
        
    weather_raw_data = pd.read_csv("data/raw/" + WEATHER_FILENAME + EXT, skipinitialspace=True)
    weather_raw_data = weather_raw_data.fillna(0)

    weather_dataset = weather_raw_data
    DONT_ERASE_WINDOW = WEATHER_WINDOWSIZE

    to_remove = ["Unnamed"]
    for s in range(2, 10): #2-9
        if s != DONT_ERASE_WINDOW:
            to_remove.append("window = " + str(s))

    print(to_remove)

    cols_to_remove = []
    cols = weather_dataset.columns
    for c in range(len(cols)):
        for r in to_remove:
            if str(r) in cols[c]:
                print(str(c) + " = " + cols[c])
                cols_to_remove.append(c)

    weather_dataset = weather_dataset.drop(weather_dataset.columns[[cols_to_remove]], axis=1)

    ##################### EXPORTING TO CSV #####################
    FILENAME = "eng_win" + str(WEATHER_WINDOWSIZE) + "_flood_" + YEAR
    
    print("exporting " + FILENAME)
    weather_dataset.to_csv("data/" + TYPE + "/" + FILENAME + EXT, encoding='utf-8', index=False)
    print("exported " + FILENAME + "\n\n")
    ############################################################
    
    
print("--END--")

# %%
for i in range(WINDOW_START, WINDOW_END):
    WEATHER_WINDOWSIZE = i
    #engineered_noeng_wwo_Taft-Ave._2015
    if TRANSFORMED and TYPE =="wwo":
        WEATHER_FILENAME = "engineered_noeng_" + TYPE + "_" + ROAD + "_" + YEAR + "_transformed"
    else:
        WEATHER_FILENAME = "engineered_noeng_" + TYPE + "_" + ROAD + "_" + YEAR

    if TYPE == "wwo":
        WEATHER_FILENAME = "engineered_noeng_" + TYPE + "_" + ROAD + "_" + YEAR
        
    weather_raw_data = pd.read_csv("data/raw/" + WEATHER_FILENAME + EXT, skipinitialspace=True)
    weather_raw_data = weather_raw_data.fillna(0)

    weather_dataset = weather_raw_data
    DONT_ERASE_WINDOW = WEATHER_WINDOWSIZE

    to_remove = ["Unnamed"]
    for s in range(2, 10): #2-9
        if s != DONT_ERASE_WINDOW:
            to_remove.append("window = " + str(s))

    print(to_remove)

    cols_to_remove = []
    cols = weather_dataset.columns
    for c in range(len(cols)):
        for r in to_remove:
            if str(r) in cols[c]:
                print(str(c) + " = " + cols[c])
                cols_to_remove.append(c)

    weather_dataset = weather_dataset.drop(weather_dataset.columns[[cols_to_remove]], axis=1)

    ##################### EXPORTING TO CSV #####################
    if TRANSFORMED:
        FILENAME = "eng_win" + str(WEATHER_WINDOWSIZE) + "_" + TYPE + "_" + ROAD + "_" + YEAR + "_transformed"    
    else:
        FILENAME = "eng_win" + str(WEATHER_WINDOWSIZE) + "_" + TYPE + "_" + ROAD + "_" + YEAR
    
    print("exporting " + FILENAME)
    weather_dataset.to_csv("data/" + TYPE + "/" + FILENAME + EXT, encoding='utf-8', index=False)
    print("exported " + FILENAME + "\n\n")
    ############################################################
    
    
print("--END--")
# Out:
# ['Unnamed', 'window = 3', 'window = 4', 'window = 5', 'window = 6', 'window = 7', 'window = 8', 'window = 9']
# 13 = Unnamed: 13
# 14 = Unnamed: 14
# 15 = Unnamed: 15
# 16 = Unnamed: 16
# 17 = Unnamed: 17
# 18 = Unnamed: 18
# 19 = Unnamed: 19
# 20 = Unnamed: 20
# 21 = Unnamed: 21
# 22 = Unnamed: 22
# 23 = Unnamed: 23
# 24 = Unnamed: 24
# 25 = Unnamed: 25
# 33 = tempC_Rmean (window = 3)
# 34 = tempC_Rmin  (window = 3)
# 35 = tempC_Rmax  (window = 3)
# 36 = tempC_Rmean (window = 4)
# 37 = tempC_Rmin  (window = 4)
# 38 = tempC_Rmax  (window = 4)
# 39 = tempC_Rmean (window = 5)
# 40 = tempC_Rmin  (window = 5)
# 41 = tempC_Rmax  (window = 5)
# 42 = tempC_Rmean (window = 6)
# 43 = tempC_Rmin  (window = 6)
# 44 = tempC_Rmax  (window = 6)
# 45 = tempC_Rmean (window = 7)
# 46 = tempC_Rmin  (window = 7)
# 47 = tempC_Rmax  (window = 7)
# 48 = tempC_Rmean (window = 8)
# 49 = tempC_Rmin  (window = 8)
# 50 = tempC_Rmax  (window = 8)
# 51 = tempC_Rmean (window = 9)
# 52 = tempC_Rmin  (window = 9)
# 53 = tempC_Rmax  (window = 9)
# 61 = windspeedKmph_Rmean (window = 3)
# 62 = windspeedKmph_Rmin  (window = 3)
# 63 = windspeedKmph_Rmax  (window = 3)
# 64 = windspeedKmph_Rmean (window = 4)
# 65 = windspeedKmph_Rmin  (window = 4)
# 66 = windspeedKmph_Rmax  (window = 4)
# 67 = windspeedKmph_Rmean (window = 5)
# 68 = windspeedKmph_Rmin  (window = 5)
# 69 = windspeedKmph_Rmax  (window = 5)
# 70 = windspeedKmph_Rmean (window = 6)
# 71 = windspeedKmph_Rmin  (window = 6)
# 72 = windspeedKmph_Rmax  (window = 6)
# 73 = windspeedKmph_Rmean (window = 7)
# 74 = windspeedKmph_Rmin  (window = 7)
# 75 = windspeedKmph_Rmax  (window = 7)
# 76 = windspeedKmph_Rmean (window = 8)
# 77 = windspeedKmph_Rmin  (window = 8)
# 78 = windspeedKmph_Rmax  (window = 8)
# 79 = windspeedKmph_Rmean (window = 9)
# 80 = windspeedKmph_Rmin  (window = 9)
# 81 = windspeedKmph_Rmax  (window = 9)
# 89 = cond_Rmean (window = 3)
# 90 = cond_Rmin  (window = 3)
# 91 = cond_Rmax  (window = 3)
# 92 = cond_Rmean (window = 4)
# 93 = cond_Rmin  (window = 4)
# 94 = cond_Rmax  (window = 4)
# 95 = cond_Rmean (window = 5)
# 96 = cond_Rmin  (window = 5)
# 97 = cond_Rmax  (window = 5)
# 98 = cond_Rmean (window = 6)
# 99 = cond_Rmin  (window = 6)
# 100 = cond_Rmax  (window = 6)
# 101 = cond_Rmean (window = 7)
# 102 = cond_Rmin  (window = 7)
# 103 = cond_Rmax  (window = 7)
# 104 = cond_Rmean (window = 8)
# 105 = cond_Rmin  (window = 8)
# 106 = cond_Rmax  (window = 8)
# 107 = cond_Rmean (window = 9)
# 108 = cond_Rmin  (window = 9)
# 109 = cond_Rmax  (window = 9)
# 117 = precipMM_Rmean (window = 3)
# 118 = precipMM_Rmin  (window = 3)
# 119 = precipMM_Rmax  (window = 3)
# 120 = precipMM_Rmean (window = 4)
# 121 = precipMM_Rmin  (window = 4)
# 122 = precipMM_Rmax  (window = 4)
# 123 = precipMM_Rmean (window = 5)
# 124 = precipMM_Rmin  (window = 5)
# 125 = precipMM_Rmax  (window = 5)
# 126 = precipMM_Rmean (window = 6)
# 127 = precipMM_Rmin  (window = 6)
# 128 = precipMM_Rmax  (window = 6)
# 129 = precipMM_Rmean (window = 7)
# 130 = precipMM_Rmin  (window = 7)
# 131 = precipMM_Rmax  (window = 7)
# 132 = precipMM_Rmean (window = 8)
# 133 = precipMM_Rmin  (window = 8)
# 134 = precipMM_Rmax  (window = 8)
# 135 = precipMM_Rmean (window = 9)
# 136 = precipMM_Rmin  (window = 9)
# 137 = precipMM_Rmax  (window = 9)
# 145 = humidity_Rmean (window = 3)
# 146 = humidity_Rmin  (window = 3)
# 147 = humidity_Rmax  (window = 3)
# 148 = humidity_Rmean (window = 4)
# 149 = humidity_Rmin  (window = 4)
# 150 = humidity_Rmax  (window = 4)
# 151 = humidity_Rmean (window = 5)
# 152 = humidity_Rmin  (window = 5)
# 153 = humidity_Rmax  (window = 5)
# 154 = humidity_Rmean (window = 6)
# 155 = humidity_Rmin  (window = 6)
# 156 = humidity_Rmax  (window = 6)
# 157 = humidity_Rmean (window = 7)
# 158 = humidity_Rmin  (window = 7)
# 159 = humidity_Rmax  (window = 7)
# 160 = humidity_Rmean (window = 8)
# 161 = humidity_Rmin  (window = 8)
# 162 = humidity_Rmax  (window = 8)
# 163 = humidity_Rmean (window = 9)
# 164 = humidity_Rmin  (window = 9)
# 165 = humidity_Rmax  (window = 9)
# 173 = visibility_Rmean (window = 3)
# 174 = visibility_Rmin  (window = 3)
# 175 = visibility_Rmax  (window = 3)
# 176 = visibility_Rmean (window = 4)
# 177 = visibility_Rmin  (window = 4)
# 178 = visibility_Rmax  (window = 4)
# 179 = visibility_Rmean (window = 5)
# 180 = visibility_Rmin  (window = 5)
# 181 = visibility_Rmax  (window = 5)
# 182 = visibility_Rmean (window = 6)
# 183 = visibility_Rmin  (window = 6)
# 184 = visibility_Rmax  (window = 6)
# 185 = visibility_Rmean (window = 7)
# 186 = visibility_Rmin  (window = 7)
# 187 = visibility_Rmax  (window = 7)
# 188 = visibility_Rmean (window = 8)
# 189 = visibility_Rmin  (window = 8)
# 190 = visibility_Rmax  (window = 8)
# 191 = visibility_Rmean (window = 9)
# 192 = visibility_Rmin  (window = 9)
# 193 = visibility_Rmax  (window = 9)
# 201 = pressure_Rmean (window = 3)
# 202 = pressure_Rmin  (window = 3)
# 203 = pressure_Rmax  (window = 3)
# 204 = pressure_Rmean (window = 4)
# 205 = pressure_Rmin  (window = 4)
# 206 = pressure_Rmax  (window = 4)
# 207 = pressure_Rmean (window = 5)
# 208 = pressure_Rmin  (window = 5)
# 209 = pressure_Rmax  (window = 5)
# 210 = pressure_Rmean (window = 6)
# 211 = pressure_Rmin  (window = 6)
# 212 = pressure_Rmax  (window = 6)
# 213 = pressure_Rmean (window = 7)
# 214 = pressure_Rmin  (window = 7)
# 215 = pressure_Rmax  (window = 7)
# 216 = pressure_Rmean (window = 8)
# 217 = pressure_Rmin  (window = 8)
# 218 = pressure_Rmax  (window = 8)
# 219 = pressure_Rmean (window = 9)
# 220 = pressure_Rmin  (window = 9)
# 221 = pressure_Rmax  (window = 9)
# 229 = cloudcover_Rmean (window = 3)
# 230 = cloudcover_Rmin  (window = 3)
# 231 = cloudcover_Rmax  (window = 3)
# 232 = cloudcover_Rmean (window = 4)
# 233 = cloudcover_Rmin  (window = 4)
# 234 = cloudcover_Rmax  (window = 4)
# 235 = cloudcover_Rmean (window = 5)
# 236 = cloudcover_Rmin  (window = 5)
# 237 = cloudcover_Rmax  (window = 5)
# 238 = cloudcover_Rmean (window = 6)
# 239 = cloudcover_Rmin  (window = 6)
# 240 = cloudcover_Rmax  (window = 6)
# 241 = cloudcover_Rmean (window = 7)
# 242 = cloudcover_Rmin  (window = 7)
# 243 = cloudcover_Rmax  (window = 7)
# 244 = cloudcover_Rmean (window = 8)
# 245 = cloudcover_Rmin  (window = 8)
# 246 = cloudcover_Rmax  (window = 8)
# 247 = cloudcover_Rmean (window = 9)
# 248 = cloudcover_Rmin  (window = 9)
# 249 = cloudcover_Rmax  (window = 9)
# 257 = dewPointC_Rmean (window = 3)
# 258 = dewPointC_Rmin  (window = 3)
# 259 = dewPointC_Rmax  (window = 3)
# 260 = dewPointC_Rmean (window = 4)
# 261 = dewPointC_Rmin  (window = 4)
# 262 = dewPointC_Rmax  (window = 4)
# 263 = dewPointC_Rmean (window = 5)
# 264 = dewPointC_Rmin  (window = 5)
# 265 = dewPointC_Rmax  (window = 5)
# 266 = dewPointC_Rmean (window = 6)
# 267 = dewPointC_Rmin  (window = 6)
# 268 = dewPointC_Rmax  (window = 6)
# 269 = dewPointC_Rmean (window = 7)
# 270 = dewPointC_Rmin  (window = 7)
# 271 = dewPointC_Rmax  (window = 7)
# 272 = dewPointC_Rmean (window = 8)
# 273 = dewPointC_Rmin  (window = 8)
# 274 = dewPointC_Rmax  (window = 8)
# 275 = dewPointC_Rmean (window = 9)
# 276 = dewPointC_Rmin  (window = 9)
# 277 = dewPointC_Rmax  (window = 9)
# 285 = windGustKmph_Rmean (window = 3)
# 286 = windGustKmph_Rmin  (window = 3)
# 287 = windGustKmph_Rmax  (window = 3)
# 288 = windGustKmph_Rmean (window = 4)
# 289 = windGustKmph_Rmin  (window = 4)
# 290 = windGustKmph_Rmax  (window = 4)
# 291 = windGustKmph_Rmean (window = 5)
# 292 = windGustKmph_Rmin  (window = 5)
# 293 = windGustKmph_Rmax  (window = 5)
# 294 = windGustKmph_Rmean (window = 6)
# 295 = windGustKmph_Rmin  (window = 6)
# 296 = windGustKmph_Rmax  (window = 6)
# 297 = windGustKmph_Rmean (window = 7)
# 298 = windGustKmph_Rmin  (window = 7)
# 299 = windGustKmph_Rmax  (window = 7)
# 300 = windGustKmph_Rmean (window = 8)
# 301 = windGustKmph_Rmin  (window = 8)
# 302 = windGustKmph_Rmax  (window = 8)
# 303 = windGustKmph_Rmean (window = 9)
# 304 = windGustKmph_Rmin  (window = 9)
# 305 = windGustKmph_Rmax  (window = 9)
# exporting eng_win2_wwo_Taft Ave._2015
# exported eng_win2_wwo_Taft Ave._2015
#
#
# ['Unnamed', 'window = 2', 'window = 4', 'window = 5', 'window = 6', 'window = 7', 'window = 8', 'window = 9']
# 13 = Unnamed: 13
# 14 = Unnamed: 14
# 15 = Unnamed: 15
# 16 = Unnamed: 16
# 17 = Unnamed: 17
# 18 = Unnamed: 18
# 19 = Unnamed: 19
# 20 = Unnamed: 20
# 21 = Unnamed: 21
# 22 = Unnamed: 22
# 23 = Unnamed: 23
# 24 = Unnamed: 24
# 25 = Unnamed: 25
# 30 = tempC_Rmean (window = 2)
# 31 = tempC_Rmin  (window = 2)
# 32 = tempC_Rmax  (window = 2)
# 36 = tempC_Rmean (window = 4)
# 37 = tempC_Rmin  (window = 4)
# 38 = tempC_Rmax  (window = 4)
# 39 = tempC_Rmean (window = 5)
# 40 = tempC_Rmin  (window = 5)
# 41 = tempC_Rmax  (window = 5)
# 42 = tempC_Rmean (window = 6)
# 43 = tempC_Rmin  (window = 6)
# 44 = tempC_Rmax  (window = 6)
# 45 = tempC_Rmean (window = 7)
# 46 = tempC_Rmin  (window = 7)
# 47 = tempC_Rmax  (window = 7)
# 48 = tempC_Rmean (window = 8)
# 49 = tempC_Rmin  (window = 8)
# 50 = tempC_Rmax  (window = 8)
# 51 = tempC_Rmean (window = 9)
# 52 = tempC_Rmin  (window = 9)
# 53 = tempC_Rmax  (window = 9)
# 58 = windspeedKmph_Rmean (window = 2)
# 59 = windspeedKmph_Rmin  (window = 2)
# 60 = windspeedKmph_Rmax  (window = 2)
# 64 = windspeedKmph_Rmean (window = 4)
# 65 = windspeedKmph_Rmin  (window = 4)
# 66 = windspeedKmph_Rmax  (window = 4)
# 67 = windspeedKmph_Rmean (window = 5)
# 68 = windspeedKmph_Rmin  (window = 5)
# 69 = windspeedKmph_Rmax  (window = 5)
# 70 = windspeedKmph_Rmean (window = 6)
# 71 = windspeedKmph_Rmin  (window = 6)
# 72 = windspeedKmph_Rmax  (window = 6)
# 73 = windspeedKmph_Rmean (window = 7)
# 74 = windspeedKmph_Rmin  (window = 7)
# 75 = windspeedKmph_Rmax  (window = 7)
# 76 = windspeedKmph_Rmean (window = 8)
# 77 = windspeedKmph_Rmin  (window = 8)
# 78 = windspeedKmph_Rmax  (window = 8)
# 79 = windspeedKmph_Rmean (window = 9)
# 80 = windspeedKmph_Rmin  (window = 9)
# 81 = windspeedKmph_Rmax  (window = 9)
# 86 = cond_Rmean (window = 2)
# 87 = cond_Rmin  (window = 2)
# 88 = cond_Rmax  (window = 2)
# 92 = cond_Rmean (window = 4)
# 93 = cond_Rmin  (window = 4)
# 94 = cond_Rmax  (window = 4)
# 95 = cond_Rmean (window = 5)
# 96 = cond_Rmin  (window = 5)
# 97 = cond_Rmax  (window = 5)
# 98 = cond_Rmean (window = 6)
# 99 = cond_Rmin  (window = 6)
# 100 = cond_Rmax  (window = 6)
# 101 = cond_Rmean (window = 7)
# 102 = cond_Rmin  (window = 7)
# 103 = cond_Rmax  (window = 7)
# 104 = cond_Rmean (window = 8)
# 105 = cond_Rmin  (window = 8)
# 106 = cond_Rmax  (window = 8)
# 107 = cond_Rmean (window = 9)
# 108 = cond_Rmin  (window = 9)
# 109 = cond_Rmax  (window = 9)
# 114 = precipMM_Rmean (window = 2)
# 115 = precipMM_Rmin  (window = 2)
# 116 = precipMM_Rmax  (window = 2)
# 120 = precipMM_Rmean (window = 4)
# 121 = precipMM_Rmin  (window = 4)
# 122 = precipMM_Rmax  (window = 4)
# 123 = precipMM_Rmean (window = 5)
# 124 = precipMM_Rmin  (window = 5)
# 125 = precipMM_Rmax  (window = 5)
# 126 = precipMM_Rmean (window = 6)
# 127 = precipMM_Rmin  (window = 6)
# 128 = precipMM_Rmax  (window = 6)
# 129 = precipMM_Rmean (window = 7)
# 130 = precipMM_Rmin  (window = 7)
# 131 = precipMM_Rmax  (window = 7)
# 132 = precipMM_Rmean (window = 8)
# 133 = precipMM_Rmin  (window = 8)
# 134 = precipMM_Rmax  (window = 8)
# 135 = precipMM_Rmean (window = 9)
# 136 = precipMM_Rmin  (window = 9)
# 137 = precipMM_Rmax  (window = 9)
# 142 = humidity_Rmean (window = 2)
# 143 = humidity_Rmin  (window = 2)
# 144 = humidity_Rmax  (window = 2)
# 148 = humidity_Rmean (window = 4)
# 149 = humidity_Rmin  (window = 4)
# 150 = humidity_Rmax  (window = 4)
# 151 = humidity_Rmean (window = 5)
# 152 = humidity_Rmin  (window = 5)
# 153 = humidity_Rmax  (window = 5)
# 154 = humidity_Rmean (window = 6)
# 155 = humidity_Rmin  (window = 6)
# 156 = humidity_Rmax  (window = 6)
# 157 = humidity_Rmean (window = 7)
# 158 = humidity_Rmin  (window = 7)
# 159 = humidity_Rmax  (window = 7)
# 160 = humidity_Rmean (window = 8)
# 161 = humidity_Rmin  (window = 8)
# 162 = humidity_Rmax  (window = 8)
# 163 = humidity_Rmean (window = 9)
# 164 = humidity_Rmin  (window = 9)
# 165 = humidity_Rmax  (window = 9)
# 170 = visibility_Rmean (window = 2)
# 171 = visibility_Rmin  (window = 2)
# 172 = visibility_Rmax  (window = 2)
# 176 = visibility_Rmean (window = 4)
# 177 = visibility_Rmin  (window = 4)
# 178 = visibility_Rmax  (window = 4)
# 179 = visibility_Rmean (window = 5)
# 180 = visibility_Rmin  (window = 5)
# 181 = visibility_Rmax  (window = 5)
# 182 = visibility_Rmean (window = 6)
# 183 = visibility_Rmin  (window = 6)
# 184 = visibility_Rmax  (window = 6)
# 185 = visibility_Rmean (window = 7)
# 186 = visibility_Rmin  (window = 7)
# 187 = visibility_Rmax  (window = 7)
# 188 = visibility_Rmean (window = 8)
# 189 = visibility_Rmin  (window = 8)
# 190 = visibility_Rmax  (window = 8)
# 191 = visibility_Rmean (window = 9)
# 192 = visibility_Rmin  (window = 9)
# 193 = visibility_Rmax  (window = 9)
# 198 = pressure_Rmean (window = 2)
# 199 = pressure_Rmin  (window = 2)
# 200 = pressure_Rmax  (window = 2)
# 204 = pressure_Rmean (window = 4)
# 205 = pressure_Rmin  (window = 4)
# 206 = pressure_Rmax  (window = 4)
# 207 = pressure_Rmean (window = 5)
# 208 = pressure_Rmin  (window = 5)
# 209 = pressure_Rmax  (window = 5)
# 210 = pressure_Rmean (window = 6)
# 211 = pressure_Rmin  (window = 6)
# 212 = pressure_Rmax  (window = 6)
# 213 = pressure_Rmean (window = 7)
# 214 = pressure_Rmin  (window = 7)
# 215 = pressure_Rmax  (window = 7)
# 216 = pressure_Rmean (window = 8)
# 217 = pressure_Rmin  (window = 8)
# 218 = pressure_Rmax  (window = 8)
# 219 = pressure_Rmean (window = 9)
# 220 = pressure_Rmin  (window = 9)
# 221 = pressure_Rmax  (window = 9)
# 226 = cloudcover_Rmean (window = 2)
# 227 = cloudcover_Rmin  (window = 2)
# 228 = cloudcover_Rmax  (window = 2)
# 232 = cloudcover_Rmean (window = 4)
# 233 = cloudcover_Rmin  (window = 4)
# 234 = cloudcover_Rmax  (window = 4)
# 235 = cloudcover_Rmean (window = 5)
# 236 = cloudcover_Rmin  (window = 5)
# 237 = cloudcover_Rmax  (window = 5)
# 238 = cloudcover_Rmean (window = 6)
# 239 = cloudcover_Rmin  (window = 6)
# 240 = cloudcover_Rmax  (window = 6)
# 241 = cloudcover_Rmean (window = 7)
# 242 = cloudcover_Rmin  (window = 7)
# 243 = cloudcover_Rmax  (window = 7)
# 244 = cloudcover_Rmean (window = 8)
# 245 = cloudcover_Rmin  (window = 8)
# 246 = cloudcover_Rmax  (window = 8)
# 247 = cloudcover_Rmean (window = 9)
# 248 = cloudcover_Rmin  (window = 9)
# 249 = cloudcover_Rmax  (window = 9)
# 254 = dewPointC_Rmean (window = 2)
# 255 = dewPointC_Rmin  (window = 2)
# 256 = dewPointC_Rmax  (window = 2)
# 260 = dewPointC_Rmean (window = 4)
# 261 = dewPointC_Rmin  (window = 4)
# 262 = dewPointC_Rmax  (window = 4)
# 263 = dewPointC_Rmean (window = 5)
# 264 = dewPointC_Rmin  (window = 5)
# 265 = dewPointC_Rmax  (window = 5)
# 266 = dewPointC_Rmean (window = 6)
# 267 = dewPointC_Rmin  (window = 6)
# 268 = dewPointC_Rmax  (window = 6)
# 269 = dewPointC_Rmean (window = 7)
# 270 = dewPointC_Rmin  (window = 7)
# 271 = dewPointC_Rmax  (window = 7)
# 272 = dewPointC_Rmean (window = 8)
# 273 = dewPointC_Rmin  (window = 8)
# 274 = dewPointC_Rmax  (window = 8)
# 275 = dewPointC_Rmean (window = 9)
# 276 = dewPointC_Rmin  (window = 9)
# 277 = dewPointC_Rmax  (window = 9)
# 282 = windGustKmph_Rmean (window = 2)
# 283 = windGustKmph_Rmin  (window = 2)
# 284 = windGustKmph_Rmax  (window = 2)
# 288 = windGustKmph_Rmean (window = 4)
# 289 = windGustKmph_Rmin  (window = 4)
# 290 = windGustKmph_Rmax  (window = 4)
# 291 = windGustKmph_Rmean (window = 5)
# 292 = windGustKmph_Rmin  (window = 5)
# 293 = windGustKmph_Rmax  (window = 5)
# 294 = windGustKmph_Rmean (window = 6)
# 295 = windGustKmph_Rmin  (window = 6)
# 296 = windGustKmph_Rmax  (window = 6)
# 297 = windGustKmph_Rmean (window = 7)
# 298 = windGustKmph_Rmin  (window = 7)
# 299 = windGustKmph_Rmax  (window = 7)
# 300 = windGustKmph_Rmean (window = 8)
# 301 = windGustKmph_Rmin  (window = 8)
# 302 = windGustKmph_Rmax  (window = 8)
# 303 = windGustKmph_Rmean (window = 9)
# 304 = windGustKmph_Rmin  (window = 9)
# 305 = windGustKmph_Rmax  (window = 9)
# exporting eng_win3_wwo_Taft Ave._2015
# exported eng_win3_wwo_Taft Ave._2015
#
#
# ['Unnamed', 'window = 2', 'window = 3', 'window = 5', 'window = 6', 'window = 7', 'window = 8', 'window = 9']
# 13 = Unnamed: 13
# 14 = Unnamed: 14
# 15 = Unnamed: 15
# 16 = Unnamed: 16
# 17 = Unnamed: 17
# 18 = Unnamed: 18
# 19 = Unnamed: 19
# 20 = Unnamed: 20
# 21 = Unnamed: 21
# 22 = Unnamed: 22
# 23 = Unnamed: 23
# 24 = Unnamed: 24
# 25 = Unnamed: 25
# 30 = tempC_Rmean (window = 2)
# 31 = tempC_Rmin  (window = 2)
# 32 = tempC_Rmax  (window = 2)
# 33 = tempC_Rmean (window = 3)
# 34 = tempC_Rmin  (window = 3)
# 35 = tempC_Rmax  (window = 3)
# 39 = tempC_Rmean (window = 5)
# 40 = tempC_Rmin  (window = 5)
# 41 = tempC_Rmax  (window = 5)
# 42 = tempC_Rmean (window = 6)
# 43 = tempC_Rmin  (window = 6)
# 44 = tempC_Rmax  (window = 6)
# 45 = tempC_Rmean (window = 7)
# 46 = tempC_Rmin  (window = 7)
# 47 = tempC_Rmax  (window = 7)
# 48 = tempC_Rmean (window = 8)
# 49 = tempC_Rmin  (window = 8)
# 50 = tempC_Rmax  (window = 8)
# 51 = tempC_Rmean (window = 9)
# 52 = tempC_Rmin  (window = 9)
# 53 = tempC_Rmax  (window = 9)
# 58 = windspeedKmph_Rmean (window = 2)
# 59 = windspeedKmph_Rmin  (window = 2)
# 60 = windspeedKmph_Rmax  (window = 2)
# 61 = windspeedKmph_Rmean (window = 3)
# 62 = windspeedKmph_Rmin  (window = 3)
# 63 = windspeedKmph_Rmax  (window = 3)
# 67 = windspeedKmph_Rmean (window = 5)
# 68 = windspeedKmph_Rmin  (window = 5)
# 69 = windspeedKmph_Rmax  (window = 5)
# 70 = windspeedKmph_Rmean (window = 6)
# 71 = windspeedKmph_Rmin  (window = 6)
# 72 = windspeedKmph_Rmax  (window = 6)
# 73 = windspeedKmph_Rmean (window = 7)
# 74 = windspeedKmph_Rmin  (window = 7)
# 75 = windspeedKmph_Rmax  (window = 7)
# 76 = windspeedKmph_Rmean (window = 8)
# 77 = windspeedKmph_Rmin  (window = 8)
# 78 = windspeedKmph_Rmax  (window = 8)
# 79 = windspeedKmph_Rmean (window = 9)
# 80 = windspeedKmph_Rmin  (window = 9)
# 81 = windspeedKmph_Rmax  (window = 9)
# 86 = cond_Rmean (window = 2)
# 87 = cond_Rmin  (window = 2)
# 88 = cond_Rmax  (window = 2)
# 89 = cond_Rmean (window = 3)
# 90 = cond_Rmin  (window = 3)
# 91 = cond_Rmax  (window = 3)
# 95 = cond_Rmean (window = 5)
# 96 = cond_Rmin  (window = 5)
# 97 = cond_Rmax  (window = 5)
# 98 = cond_Rmean (window = 6)
# 99 = cond_Rmin  (window = 6)
# 100 = cond_Rmax  (window = 6)
# 101 = cond_Rmean (window = 7)
# 102 = cond_Rmin  (window = 7)
# 103 = cond_Rmax  (window = 7)
# 104 = cond_Rmean (window = 8)
# 105 = cond_Rmin  (window = 8)
# 106 = cond_Rmax  (window = 8)
# 107 = cond_Rmean (window = 9)
# 108 = cond_Rmin  (window = 9)
# 109 = cond_Rmax  (window = 9)
# 114 = precipMM_Rmean (window = 2)
# 115 = precipMM_Rmin  (window = 2)
# 116 = precipMM_Rmax  (window = 2)
# 117 = precipMM_Rmean (window = 3)
# 118 = precipMM_Rmin  (window = 3)
# 119 = precipMM_Rmax  (window = 3)
# 123 = precipMM_Rmean (window = 5)
# 124 = precipMM_Rmin  (window = 5)
# 125 = precipMM_Rmax  (window = 5)
# 126 = precipMM_Rmean (window = 6)
# 127 = precipMM_Rmin  (window = 6)
# 128 = precipMM_Rmax  (window = 6)
# 129 = precipMM_Rmean (window = 7)
# 130 = precipMM_Rmin  (window = 7)
# 131 = precipMM_Rmax  (window = 7)
# 132 = precipMM_Rmean (window = 8)
# 133 = precipMM_Rmin  (window = 8)
# 134 = precipMM_Rmax  (window = 8)
# 135 = precipMM_Rmean (window = 9)
# 136 = precipMM_Rmin  (window = 9)
# 137 = precipMM_Rmax  (window = 9)
# 142 = humidity_Rmean (window = 2)
# 143 = humidity_Rmin  (window = 2)
# 144 = humidity_Rmax  (window = 2)
# 145 = humidity_Rmean (window = 3)
# 146 = humidity_Rmin  (window = 3)
# 147 = humidity_Rmax  (window = 3)
# 151 = humidity_Rmean (window = 5)
# 152 = humidity_Rmin  (window = 5)
# 153 = humidity_Rmax  (window = 5)
# 154 = humidity_Rmean (window = 6)
# 155 = humidity_Rmin  (window = 6)
# 156 = humidity_Rmax  (window = 6)
# 157 = humidity_Rmean (window = 7)
# 158 = humidity_Rmin  (window = 7)
# 159 = humidity_Rmax  (window = 7)
# 160 = humidity_Rmean (window = 8)
# 161 = humidity_Rmin  (window = 8)
# 162 = humidity_Rmax  (window = 8)
# 163 = humidity_Rmean (window = 9)
# 164 = humidity_Rmin  (window = 9)
# 165 = humidity_Rmax  (window = 9)
# 170 = visibility_Rmean (window = 2)
# 171 = visibility_Rmin  (window = 2)
# 172 = visibility_Rmax  (window = 2)
# 173 = visibility_Rmean (window = 3)
# 174 = visibility_Rmin  (window = 3)
# 175 = visibility_Rmax  (window = 3)
# 179 = visibility_Rmean (window = 5)
# 180 = visibility_Rmin  (window = 5)
# 181 = visibility_Rmax  (window = 5)
# 182 = visibility_Rmean (window = 6)
# 183 = visibility_Rmin  (window = 6)
# 184 = visibility_Rmax  (window = 6)
# 185 = visibility_Rmean (window = 7)
# 186 = visibility_Rmin  (window = 7)
# 187 = visibility_Rmax  (window = 7)
# 188 = visibility_Rmean (window = 8)
# 189 = visibility_Rmin  (window = 8)
# 190 = visibility_Rmax  (window = 8)
# 191 = visibility_Rmean (window = 9)
# 192 = visibility_Rmin  (window = 9)
# 193 = visibility_Rmax  (window = 9)
# 198 = pressure_Rmean (window = 2)
# 199 = pressure_Rmin  (window = 2)
# 200 = pressure_Rmax  (window = 2)
# 201 = pressure_Rmean (window = 3)
# 202 = pressure_Rmin  (window = 3)
# 203 = pressure_Rmax  (window = 3)
# 207 = pressure_Rmean (window = 5)
# 208 = pressure_Rmin  (window = 5)
# 209 = pressure_Rmax  (window = 5)
# 210 = pressure_Rmean (window = 6)
# 211 = pressure_Rmin  (window = 6)
# 212 = pressure_Rmax  (window = 6)
# 213 = pressure_Rmean (window = 7)
# 214 = pressure_Rmin  (window = 7)
# 215 = pressure_Rmax  (window = 7)
# 216 = pressure_Rmean (window = 8)
# 217 = pressure_Rmin  (window = 8)
# 218 = pressure_Rmax  (window = 8)
# 219 = pressure_Rmean (window = 9)
# 220 = pressure_Rmin  (window = 9)
# 221 = pressure_Rmax  (window = 9)
# 226 = cloudcover_Rmean (window = 2)
# 227 = cloudcover_Rmin  (window = 2)
# 228 = cloudcover_Rmax  (window = 2)
# 229 = cloudcover_Rmean (window = 3)
# 230 = cloudcover_Rmin  (window = 3)
# 231 = cloudcover_Rmax  (window = 3)
# 235 = cloudcover_Rmean (window = 5)
# 236 = cloudcover_Rmin  (window = 5)
# 237 = cloudcover_Rmax  (window = 5)
# 238 = cloudcover_Rmean (window = 6)
# 239 = cloudcover_Rmin  (window = 6)
# 240 = cloudcover_Rmax  (window = 6)
# 241 = cloudcover_Rmean (window = 7)
# 242 = cloudcover_Rmin  (window = 7)
# 243 = cloudcover_Rmax  (window = 7)
# 244 = cloudcover_Rmean (window = 8)
# 245 = cloudcover_Rmin  (window = 8)
# 246 = cloudcover_Rmax  (window = 8)
# 247 = cloudcover_Rmean (window = 9)
# 248 = cloudcover_Rmin  (window = 9)
# 249 = cloudcover_Rmax  (window = 9)
# 254 = dewPointC_Rmean (window = 2)
# 255 = dewPointC_Rmin  (window = 2)
# 256 = dewPointC_Rmax  (window = 2)
# 257 = dewPointC_Rmean (window = 3)
# 258 = dewPointC_Rmin  (window = 3)
# 259 = dewPointC_Rmax  (window = 3)
# 263 = dewPointC_Rmean (window = 5)
# 264 = dewPointC_Rmin  (window = 5)
# 265 = dewPointC_Rmax  (window = 5)
# 266 = dewPointC_Rmean (window = 6)
# 267 = dewPointC_Rmin  (window = 6)
# 268 = dewPointC_Rmax  (window = 6)
# 269 = dewPointC_Rmean (window = 7)
# 270 = dewPointC_Rmin  (window = 7)
# 271 = dewPointC_Rmax  (window = 7)
# 272 = dewPointC_Rmean (window = 8)
# 273 = dewPointC_Rmin  (window = 8)
# 274 = dewPointC_Rmax  (window = 8)
# 275 = dewPointC_Rmean (window = 9)
# 276 = dewPointC_Rmin  (window = 9)
# 277 = dewPointC_Rmax  (window = 9)
# 282 = windGustKmph_Rmean (window = 2)
# 283 = windGustKmph_Rmin  (window = 2)
# 284 = windGustKmph_Rmax  (window = 2)
# 285 = windGustKmph_Rmean (window = 3)
# 286 = windGustKmph_Rmin  (window = 3)
# 287 = windGustKmph_Rmax  (window = 3)
# 291 = windGustKmph_Rmean (window = 5)
# 292 = windGustKmph_Rmin  (window = 5)
# 293 = windGustKmph_Rmax  (window = 5)
# 294 = windGustKmph_Rmean (window = 6)
# 295 = windGustKmph_Rmin  (window = 6)
# 296 = windGustKmph_Rmax  (window = 6)
# 297 = windGustKmph_Rmean (window = 7)
# 298 = windGustKmph_Rmin  (window = 7)
# 299 = windGustKmph_Rmax  (window = 7)
# 300 = windGustKmph_Rmean (window = 8)
# 301 = windGustKmph_Rmin  (window = 8)
# 302 = windGustKmph_Rmax  (window = 8)
# 303 = windGustKmph_Rmean (window = 9)
# 304 = windGustKmph_Rmin  (window = 9)
# 305 = windGustKmph_Rmax  (window = 9)
# exporting eng_win4_wwo_Taft Ave._2015
# exported eng_win4_wwo_Taft Ave._2015
#
#
# ['Unnamed', 'window = 2', 'window = 3', 'window = 4', 'window = 6', 'window = 7', 'window = 8', 'window = 9']
# 13 = Unnamed: 13
# 14 = Unnamed: 14
# 15 = Unnamed: 15
# 16 = Unnamed: 16
# 17 = Unnamed: 17
# 18 = Unnamed: 18
# 19 = Unnamed: 19
# 20 = Unnamed: 20
# 21 = Unnamed: 21
# 22 = Unnamed: 22
# 23 = Unnamed: 23
# 24 = Unnamed: 24
# 25 = Unnamed: 25
# 30 = tempC_Rmean (window = 2)
# 31 = tempC_Rmin  (window = 2)
# 32 = tempC_Rmax  (window = 2)
# 33 = tempC_Rmean (window = 3)
# 34 = tempC_Rmin  (window = 3)
# 35 = tempC_Rmax  (window = 3)
# 36 = tempC_Rmean (window = 4)
# 37 = tempC_Rmin  (window = 4)
# 38 = tempC_Rmax  (window = 4)
# 42 = tempC_Rmean (window = 6)
# 43 = tempC_Rmin  (window = 6)
# 44 = tempC_Rmax  (window = 6)
# 45 = tempC_Rmean (window = 7)
# 46 = tempC_Rmin  (window = 7)
# 47 = tempC_Rmax  (window = 7)
# 48 = tempC_Rmean (window = 8)
# 49 = tempC_Rmin  (window = 8)
# 50 = tempC_Rmax  (window = 8)
# 51 = tempC_Rmean (window = 9)
# 52 = tempC_Rmin  (window = 9)
# 53 = tempC_Rmax  (window = 9)
# 58 = windspeedKmph_Rmean (window = 2)
# 59 = windspeedKmph_Rmin  (window = 2)
# 60 = windspeedKmph_Rmax  (window = 2)
# 61 = windspeedKmph_Rmean (window = 3)
# 62 = windspeedKmph_Rmin  (window = 3)
# 63 = windspeedKmph_Rmax  (window = 3)
# 64 = windspeedKmph_Rmean (window = 4)
# 65 = windspeedKmph_Rmin  (window = 4)
# 66 = windspeedKmph_Rmax  (window = 4)
# 70 = windspeedKmph_Rmean (window = 6)
# 71 = windspeedKmph_Rmin  (window = 6)
# 72 = windspeedKmph_Rmax  (window = 6)
# 73 = windspeedKmph_Rmean (window = 7)
# 74 = windspeedKmph_Rmin  (window = 7)
# 75 = windspeedKmph_Rmax  (window = 7)
# 76 = windspeedKmph_Rmean (window = 8)
# 77 = windspeedKmph_Rmin  (window = 8)
# 78 = windspeedKmph_Rmax  (window = 8)
# 79 = windspeedKmph_Rmean (window = 9)
# 80 = windspeedKmph_Rmin  (window = 9)
# 81 = windspeedKmph_Rmax  (window = 9)
# 86 = cond_Rmean (window = 2)
# 87 = cond_Rmin  (window = 2)
# 88 = cond_Rmax  (window = 2)
# 89 = cond_Rmean (window = 3)
# 90 = cond_Rmin  (window = 3)
# 91 = cond_Rmax  (window = 3)
# 92 = cond_Rmean (window = 4)
# 93 = cond_Rmin  (window = 4)
# 94 = cond_Rmax  (window = 4)
# 98 = cond_Rmean (window = 6)
# 99 = cond_Rmin  (window = 6)
# 100 = cond_Rmax  (window = 6)
# 101 = cond_Rmean (window = 7)
# 102 = cond_Rmin  (window = 7)
# 103 = cond_Rmax  (window = 7)
# 104 = cond_Rmean (window = 8)
# 105 = cond_Rmin  (window = 8)
# 106 = cond_Rmax  (window = 8)
# 107 = cond_Rmean (window = 9)
# 108 = cond_Rmin  (window = 9)
# 109 = cond_Rmax  (window = 9)
# 114 = precipMM_Rmean (window = 2)
# 115 = precipMM_Rmin  (window = 2)
# 116 = precipMM_Rmax  (window = 2)
# 117 = precipMM_Rmean (window = 3)
# 118 = precipMM_Rmin  (window = 3)
# 119 = precipMM_Rmax  (window = 3)
# 120 = precipMM_Rmean (window = 4)
# 121 = precipMM_Rmin  (window = 4)
# 122 = precipMM_Rmax  (window = 4)
# 126 = precipMM_Rmean (window = 6)
# 127 = precipMM_Rmin  (window = 6)
# 128 = precipMM_Rmax  (window = 6)
# 129 = precipMM_Rmean (window = 7)
# 130 = precipMM_Rmin  (window = 7)
# 131 = precipMM_Rmax  (window = 7)
# 132 = precipMM_Rmean (window = 8)
# 133 = precipMM_Rmin  (window = 8)
# 134 = precipMM_Rmax  (window = 8)
# 135 = precipMM_Rmean (window = 9)
# 136 = precipMM_Rmin  (window = 9)
# 137 = precipMM_Rmax  (window = 9)
# 142 = humidity_Rmean (window = 2)
# 143 = humidity_Rmin  (window = 2)
# 144 = humidity_Rmax  (window = 2)
# 145 = humidity_Rmean (window = 3)
# 146 = humidity_Rmin  (window = 3)
# 147 = humidity_Rmax  (window = 3)
# 148 = humidity_Rmean (window = 4)
# 149 = humidity_Rmin  (window = 4)
# 150 = humidity_Rmax  (window = 4)
# 154 = humidity_Rmean (window = 6)
# 155 = humidity_Rmin  (window = 6)
# 156 = humidity_Rmax  (window = 6)
# 157 = humidity_Rmean (window = 7)
# 158 = humidity_Rmin  (window = 7)
# 159 = humidity_Rmax  (window = 7)
# 160 = humidity_Rmean (window = 8)
# 161 = humidity_Rmin  (window = 8)
# 162 = humidity_Rmax  (window = 8)
# 163 = humidity_Rmean (window = 9)
# 164 = humidity_Rmin  (window = 9)
# 165 = humidity_Rmax  (window = 9)
# 170 = visibility_Rmean (window = 2)
# 171 = visibility_Rmin  (window = 2)
# 172 = visibility_Rmax  (window = 2)
# 173 = visibility_Rmean (window = 3)
# 174 = visibility_Rmin  (window = 3)
# 175 = visibility_Rmax  (window = 3)
# 176 = visibility_Rmean (window = 4)
# 177 = visibility_Rmin  (window = 4)
# 178 = visibility_Rmax  (window = 4)
# 182 = visibility_Rmean (window = 6)
# 183 = visibility_Rmin  (window = 6)
# 184 = visibility_Rmax  (window = 6)
# 185 = visibility_Rmean (window = 7)
# 186 = visibility_Rmin  (window = 7)
# 187 = visibility_Rmax  (window = 7)
# 188 = visibility_Rmean (window = 8)
# 189 = visibility_Rmin  (window = 8)
# 190 = visibility_Rmax  (window = 8)
# 191 = visibility_Rmean (window = 9)
# 192 = visibility_Rmin  (window = 9)
# 193 = visibility_Rmax  (window = 9)
# 198 = pressure_Rmean (window = 2)
# 199 = pressure_Rmin  (window = 2)
# 200 = pressure_Rmax  (window = 2)
# 201 = pressure_Rmean (window = 3)
# 202 = pressure_Rmin  (window = 3)
# 203 = pressure_Rmax  (window = 3)
# 204 = pressure_Rmean (window = 4)
# 205 = pressure_Rmin  (window = 4)
# 206 = pressure_Rmax  (window = 4)
# 210 = pressure_Rmean (window = 6)
# 211 = pressure_Rmin  (window = 6)
# 212 = pressure_Rmax  (window = 6)
# 213 = pressure_Rmean (window = 7)
# 214 = pressure_Rmin  (window = 7)
# 215 = pressure_Rmax  (window = 7)
# 216 = pressure_Rmean (window = 8)
# 217 = pressure_Rmin  (window = 8)
# 218 = pressure_Rmax  (window = 8)
# 219 = pressure_Rmean (window = 9)
# 220 = pressure_Rmin  (window = 9)
# 221 = pressure_Rmax  (window = 9)
# 226 = cloudcover_Rmean (window = 2)
# 227 = cloudcover_Rmin  (window = 2)
# 228 = cloudcover_Rmax  (window = 2)
# 229 = cloudcover_Rmean (window = 3)
# 230 = cloudcover_Rmin  (window = 3)
# 231 = cloudcover_Rmax  (window = 3)
# 232 = cloudcover_Rmean (window = 4)
# 233 = cloudcover_Rmin  (window = 4)
# 234 = cloudcover_Rmax  (window = 4)
# 238 = cloudcover_Rmean (window = 6)
# 239 = cloudcover_Rmin  (window = 6)
# 240 = cloudcover_Rmax  (window = 6)
# 241 = cloudcover_Rmean (window = 7)
# 242 = cloudcover_Rmin  (window = 7)
# 243 = cloudcover_Rmax  (window = 7)
# 244 = cloudcover_Rmean (window = 8)
# 245 = cloudcover_Rmin  (window = 8)
# 246 = cloudcover_Rmax  (window = 8)
# 247 = cloudcover_Rmean (window = 9)
# 248 = cloudcover_Rmin  (window = 9)
# 249 = cloudcover_Rmax  (window = 9)
# 254 = dewPointC_Rmean (window = 2)
# 255 = dewPointC_Rmin  (window = 2)
# 256 = dewPointC_Rmax  (window = 2)
# 257 = dewPointC_Rmean (window = 3)
# 258 = dewPointC_Rmin  (window = 3)
# 259 = dewPointC_Rmax  (window = 3)
# 260 = dewPointC_Rmean (window = 4)
# 261 = dewPointC_Rmin  (window = 4)
# 262 = dewPointC_Rmax  (window = 4)
# 266 = dewPointC_Rmean (window = 6)
# 267 = dewPointC_Rmin  (window = 6)
# 268 = dewPointC_Rmax  (window = 6)
# 269 = dewPointC_Rmean (window = 7)
# 270 = dewPointC_Rmin  (window = 7)
# 271 = dewPointC_Rmax  (window = 7)
# 272 = dewPointC_Rmean (window = 8)
# 273 = dewPointC_Rmin  (window = 8)
# 274 = dewPointC_Rmax  (window = 8)
# 275 = dewPointC_Rmean (window = 9)
# 276 = dewPointC_Rmin  (window = 9)
# 277 = dewPointC_Rmax  (window = 9)
# 282 = windGustKmph_Rmean (window = 2)
# 283 = windGustKmph_Rmin  (window = 2)
# 284 = windGustKmph_Rmax  (window = 2)
# 285 = windGustKmph_Rmean (window = 3)
# 286 = windGustKmph_Rmin  (window = 3)
# 287 = windGustKmph_Rmax  (window = 3)
# 288 = windGustKmph_Rmean (window = 4)
# 289 = windGustKmph_Rmin  (window = 4)
# 290 = windGustKmph_Rmax  (window = 4)
# 294 = windGustKmph_Rmean (window = 6)
# 295 = windGustKmph_Rmin  (window = 6)
# 296 = windGustKmph_Rmax  (window = 6)
# 297 = windGustKmph_Rmean (window = 7)
# 298 = windGustKmph_Rmin  (window = 7)
# 299 = windGustKmph_Rmax  (window = 7)
# 300 = windGustKmph_Rmean (window = 8)
# 301 = windGustKmph_Rmin  (window = 8)
# 302 = windGustKmph_Rmax  (window = 8)
# 303 = windGustKmph_Rmean (window = 9)
# 304 = windGustKmph_Rmin  (window = 9)
# 305 = windGustKmph_Rmax  (window = 9)
# exporting eng_win5_wwo_Taft Ave._2015
# exported eng_win5_wwo_Taft Ave._2015
#
#
# ['Unnamed', 'window = 2', 'window = 3', 'window = 4', 'window = 5', 'window = 7', 'window = 8', 'window = 9']
# 13 = Unnamed: 13
# 14 = Unnamed: 14
# 15 = Unnamed: 15
# 16 = Unnamed: 16
# 17 = Unnamed: 17
# 18 = Unnamed: 18
# 19 = Unnamed: 19
# 20 = Unnamed: 20
# 21 = Unnamed: 21
# 22 = Unnamed: 22
# 23 = Unnamed: 23
# 24 = Unnamed: 24
# 25 = Unnamed: 25
# 30 = tempC_Rmean (window = 2)
# 31 = tempC_Rmin  (window = 2)
# 32 = tempC_Rmax  (window = 2)
# 33 = tempC_Rmean (window = 3)
# 34 = tempC_Rmin  (window = 3)
# 35 = tempC_Rmax  (window = 3)
# 36 = tempC_Rmean (window = 4)
# 37 = tempC_Rmin  (window = 4)
# 38 = tempC_Rmax  (window = 4)
# 39 = tempC_Rmean (window = 5)
# 40 = tempC_Rmin  (window = 5)
# 41 = tempC_Rmax  (window = 5)
# 45 = tempC_Rmean (window = 7)
# 46 = tempC_Rmin  (window = 7)
# 47 = tempC_Rmax  (window = 7)
# 48 = tempC_Rmean (window = 8)
# 49 = tempC_Rmin  (window = 8)
# 50 = tempC_Rmax  (window = 8)
# 51 = tempC_Rmean (window = 9)
# 52 = tempC_Rmin  (window = 9)
# 53 = tempC_Rmax  (window = 9)
# 58 = windspeedKmph_Rmean (window = 2)
# 59 = windspeedKmph_Rmin  (window = 2)
# 60 = windspeedKmph_Rmax  (window = 2)
# 61 = windspeedKmph_Rmean (window = 3)
# 62 = windspeedKmph_Rmin  (window = 3)
# 63 = windspeedKmph_Rmax  (window = 3)
# 64 = windspeedKmph_Rmean (window = 4)
# 65 = windspeedKmph_Rmin  (window = 4)
# 66 = windspeedKmph_Rmax  (window = 4)
# 67 = windspeedKmph_Rmean (window = 5)
# 68 = windspeedKmph_Rmin  (window = 5)
# 69 = windspeedKmph_Rmax  (window = 5)
# 73 = windspeedKmph_Rmean (window = 7)
# 74 = windspeedKmph_Rmin  (window = 7)
# 75 = windspeedKmph_Rmax  (window = 7)
# 76 = windspeedKmph_Rmean (window = 8)
# 77 = windspeedKmph_Rmin  (window = 8)
# 78 = windspeedKmph_Rmax  (window = 8)
# 79 = windspeedKmph_Rmean (window = 9)
# 80 = windspeedKmph_Rmin  (window = 9)
# 81 = windspeedKmph_Rmax  (window = 9)
# 86 = cond_Rmean (window = 2)
# 87 = cond_Rmin  (window = 2)
# 88 = cond_Rmax  (window = 2)
# 89 = cond_Rmean (window = 3)
# 90 = cond_Rmin  (window = 3)
# 91 = cond_Rmax  (window = 3)
# 92 = cond_Rmean (window = 4)
# 93 = cond_Rmin  (window = 4)
# 94 = cond_Rmax  (window = 4)
# 95 = cond_Rmean (window = 5)
# 96 = cond_Rmin  (window = 5)
# 97 = cond_Rmax  (window = 5)
# 101 = cond_Rmean (window = 7)
# 102 = cond_Rmin  (window = 7)
# 103 = cond_Rmax  (window = 7)
# 104 = cond_Rmean (window = 8)
# 105 = cond_Rmin  (window = 8)
# 106 = cond_Rmax  (window = 8)
# 107 = cond_Rmean (window = 9)
# 108 = cond_Rmin  (window = 9)
# 109 = cond_Rmax  (window = 9)
# 114 = precipMM_Rmean (window = 2)
# 115 = precipMM_Rmin  (window = 2)
# 116 = precipMM_Rmax  (window = 2)
# 117 = precipMM_Rmean (window = 3)
# 118 = precipMM_Rmin  (window = 3)
# 119 = precipMM_Rmax  (window = 3)
# 120 = precipMM_Rmean (window = 4)
# 121 = precipMM_Rmin  (window = 4)
# 122 = precipMM_Rmax  (window = 4)
# 123 = precipMM_Rmean (window = 5)
# 124 = precipMM_Rmin  (window = 5)
# 125 = precipMM_Rmax  (window = 5)
# 129 = precipMM_Rmean (window = 7)
# 130 = precipMM_Rmin  (window = 7)
# 131 = precipMM_Rmax  (window = 7)
# 132 = precipMM_Rmean (window = 8)
# 133 = precipMM_Rmin  (window = 8)
# 134 = precipMM_Rmax  (window = 8)
# 135 = precipMM_Rmean (window = 9)
# 136 = precipMM_Rmin  (window = 9)
# 137 = precipMM_Rmax  (window = 9)
# 142 = humidity_Rmean (window = 2)
# 143 = humidity_Rmin  (window = 2)
# 144 = humidity_Rmax  (window = 2)
# 145 = humidity_Rmean (window = 3)
# 146 = humidity_Rmin  (window = 3)
# 147 = humidity_Rmax  (window = 3)
# 148 = humidity_Rmean (window = 4)
# 149 = humidity_Rmin  (window = 4)
# 150 = humidity_Rmax  (window = 4)
# 151 = humidity_Rmean (window = 5)
# 152 = humidity_Rmin  (window = 5)
# 153 = humidity_Rmax  (window = 5)
# 157 = humidity_Rmean (window = 7)
# 158 = humidity_Rmin  (window = 7)
# 159 = humidity_Rmax  (window = 7)
# 160 = humidity_Rmean (window = 8)
# 161 = humidity_Rmin  (window = 8)
# 162 = humidity_Rmax  (window = 8)
# 163 = humidity_Rmean (window = 9)
# 164 = humidity_Rmin  (window = 9)
# 165 = humidity_Rmax  (window = 9)
# 170 = visibility_Rmean (window = 2)
# 171 = visibility_Rmin  (window = 2)
# 172 = visibility_Rmax  (window = 2)
# 173 = visibility_Rmean (window = 3)
# 174 = visibility_Rmin  (window = 3)
# 175 = visibility_Rmax  (window = 3)
# 176 = visibility_Rmean (window = 4)
# 177 = visibility_Rmin  (window = 4)
# 178 = visibility_Rmax  (window = 4)
# 179 = visibility_Rmean (window = 5)
# 180 = visibility_Rmin  (window = 5)
# 181 = visibility_Rmax  (window = 5)
# 185 = visibility_Rmean (window = 7)
# 186 = visibility_Rmin  (window = 7)
# 187 = visibility_Rmax  (window = 7)
# 188 = visibility_Rmean (window = 8)
# 189 = visibility_Rmin  (window = 8)
# 190 = visibility_Rmax  (window = 8)
# 191 = visibility_Rmean (window = 9)
# 192 = visibility_Rmin  (window = 9)
# 193 = visibility_Rmax  (window = 9)
# 198 = pressure_Rmean (window = 2)
# 199 = pressure_Rmin  (window = 2)
# 200 = pressure_Rmax  (window = 2)
# 201 = pressure_Rmean (window = 3)
# 202 = pressure_Rmin  (window = 3)
# 203 = pressure_Rmax  (window = 3)
# 204 = pressure_Rmean (window = 4)
# 205 = pressure_Rmin  (window = 4)
# 206 = pressure_Rmax  (window = 4)
# 207 = pressure_Rmean (window = 5)
# 208 = pressure_Rmin  (window = 5)
# 209 = pressure_Rmax  (window = 5)
# 213 = pressure_Rmean (window = 7)
# 214 = pressure_Rmin  (window = 7)
# 215 = pressure_Rmax  (window = 7)
# 216 = pressure_Rmean (window = 8)
# 217 = pressure_Rmin  (window = 8)
# 218 = pressure_Rmax  (window = 8)
# 219 = pressure_Rmean (window = 9)
# 220 = pressure_Rmin  (window = 9)
# 221 = pressure_Rmax  (window = 9)
# 226 = cloudcover_Rmean (window = 2)
# 227 = cloudcover_Rmin  (window = 2)
# 228 = cloudcover_Rmax  (window = 2)
# 229 = cloudcover_Rmean (window = 3)
# 230 = cloudcover_Rmin  (window = 3)
# 231 = cloudcover_Rmax  (window = 3)
# 232 = cloudcover_Rmean (window = 4)
# 233 = cloudcover_Rmin  (window = 4)
# 234 = cloudcover_Rmax  (window = 4)
# 235 = cloudcover_Rmean (window = 5)
# 236 = cloudcover_Rmin  (window = 5)
# 237 = cloudcover_Rmax  (window = 5)
# 241 = cloudcover_Rmean (window = 7)
# 242 = cloudcover_Rmin  (window = 7)
# 243 = cloudcover_Rmax  (window = 7)
# 244 = cloudcover_Rmean (window = 8)
# 245 = cloudcover_Rmin  (window = 8)
# 246 = cloudcover_Rmax  (window = 8)
# 247 = cloudcover_Rmean (window = 9)
# 248 = cloudcover_Rmin  (window = 9)
# 249 = cloudcover_Rmax  (window = 9)
# 254 = dewPointC_Rmean (window = 2)
# 255 = dewPointC_Rmin  (window = 2)
# 256 = dewPointC_Rmax  (window = 2)
# 257 = dewPointC_Rmean (window = 3)
# 258 = dewPointC_Rmin  (window = 3)
# 259 = dewPointC_Rmax  (window = 3)
# 260 = dewPointC_Rmean (window = 4)
# 261 = dewPointC_Rmin  (window = 4)
# 262 = dewPointC_Rmax  (window = 4)
# 263 = dewPointC_Rmean (window = 5)
# 264 = dewPointC_Rmin  (window = 5)
# 265 = dewPointC_Rmax  (window = 5)
# 269 = dewPointC_Rmean (window = 7)
# 270 = dewPointC_Rmin  (window = 7)
# 271 = dewPointC_Rmax  (window = 7)
# 272 = dewPointC_Rmean (window = 8)
# 273 = dewPointC_Rmin  (window = 8)
# 274 = dewPointC_Rmax  (window = 8)
# 275 = dewPointC_Rmean (window = 9)
# 276 = dewPointC_Rmin  (window = 9)
# 277 = dewPointC_Rmax  (window = 9)
# 282 = windGustKmph_Rmean (window = 2)
# 283 = windGustKmph_Rmin  (window = 2)
# 284 = windGustKmph_Rmax  (window = 2)
# 285 = windGustKmph_Rmean (window = 3)
# 286 = windGustKmph_Rmin  (window = 3)
# 287 = windGustKmph_Rmax  (window = 3)
# 288 = windGustKmph_Rmean (window = 4)
# 289 = windGustKmph_Rmin  (window = 4)
# 290 = windGustKmph_Rmax  (window = 4)
# 291 = windGustKmph_Rmean (window = 5)
# 292 = windGustKmph_Rmin  (window = 5)
# 293 = windGustKmph_Rmax  (window = 5)
# 297 = windGustKmph_Rmean (window = 7)
# 298 = windGustKmph_Rmin  (window = 7)
# 299 = windGustKmph_Rmax  (window = 7)
# 300 = windGustKmph_Rmean (window = 8)
# 301 = windGustKmph_Rmin  (window = 8)
# 302 = windGustKmph_Rmax  (window = 8)
# 303 = windGustKmph_Rmean (window = 9)
# 304 = windGustKmph_Rmin  (window = 9)
# 305 = windGustKmph_Rmax  (window = 9)
# exporting eng_win6_wwo_Taft Ave._2015
# exported eng_win6_wwo_Taft Ave._2015
#
#
# ['Unnamed', 'window = 2', 'window = 3', 'window = 4', 'window = 5', 'window = 6', 'window = 8', 'window = 9']
# 13 = Unnamed: 13
# 14 = Unnamed: 14
# 15 = Unnamed: 15
# 16 = Unnamed: 16
# 17 = Unnamed: 17
# 18 = Unnamed: 18
# 19 = Unnamed: 19
# 20 = Unnamed: 20
# 21 = Unnamed: 21
# 22 = Unnamed: 22
# 23 = Unnamed: 23
# 24 = Unnamed: 24
# 25 = Unnamed: 25
# 30 = tempC_Rmean (window = 2)
# 31 = tempC_Rmin  (window = 2)
# 32 = tempC_Rmax  (window = 2)
# 33 = tempC_Rmean (window = 3)
# 34 = tempC_Rmin  (window = 3)
# 35 = tempC_Rmax  (window = 3)
# 36 = tempC_Rmean (window = 4)
# 37 = tempC_Rmin  (window = 4)
# 38 = tempC_Rmax  (window = 4)
# 39 = tempC_Rmean (window = 5)
# 40 = tempC_Rmin  (window = 5)
# 41 = tempC_Rmax  (window = 5)
# 42 = tempC_Rmean (window = 6)
# 43 = tempC_Rmin  (window = 6)
# 44 = tempC_Rmax  (window = 6)
# 48 = tempC_Rmean (window = 8)
# 49 = tempC_Rmin  (window = 8)
# 50 = tempC_Rmax  (window = 8)
# 51 = tempC_Rmean (window = 9)
# 52 = tempC_Rmin  (window = 9)
# 53 = tempC_Rmax  (window = 9)
# 58 = windspeedKmph_Rmean (window = 2)
# 59 = windspeedKmph_Rmin  (window = 2)
# 60 = windspeedKmph_Rmax  (window = 2)
# 61 = windspeedKmph_Rmean (window = 3)
# 62 = windspeedKmph_Rmin  (window = 3)
# 63 = windspeedKmph_Rmax  (window = 3)
# 64 = windspeedKmph_Rmean (window = 4)
# 65 = windspeedKmph_Rmin  (window = 4)
# 66 = windspeedKmph_Rmax  (window = 4)
# 67 = windspeedKmph_Rmean (window = 5)
# 68 = windspeedKmph_Rmin  (window = 5)
# 69 = windspeedKmph_Rmax  (window = 5)
# 70 = windspeedKmph_Rmean (window = 6)
# 71 = windspeedKmph_Rmin  (window = 6)
# 72 = windspeedKmph_Rmax  (window = 6)
# 76 = windspeedKmph_Rmean (window = 8)
# 77 = windspeedKmph_Rmin  (window = 8)
# 78 = windspeedKmph_Rmax  (window = 8)
# 79 = windspeedKmph_Rmean (window = 9)
# 80 = windspeedKmph_Rmin  (window = 9)
# 81 = windspeedKmph_Rmax  (window = 9)
# 86 = cond_Rmean (window = 2)
# 87 = cond_Rmin  (window = 2)
# 88 = cond_Rmax  (window = 2)
# 89 = cond_Rmean (window = 3)
# 90 = cond_Rmin  (window = 3)
# 91 = cond_Rmax  (window = 3)
# 92 = cond_Rmean (window = 4)
# 93 = cond_Rmin  (window = 4)
# 94 = cond_Rmax  (window = 4)
# 95 = cond_Rmean (window = 5)
# 96 = cond_Rmin  (window = 5)
# 97 = cond_Rmax  (window = 5)
# 98 = cond_Rmean (window = 6)
# 99 = cond_Rmin  (window = 6)
# 100 = cond_Rmax  (window = 6)
# 104 = cond_Rmean (window = 8)
# 105 = cond_Rmin  (window = 8)
# 106 = cond_Rmax  (window = 8)
# 107 = cond_Rmean (window = 9)
# 108 = cond_Rmin  (window = 9)
# 109 = cond_Rmax  (window = 9)
# 114 = precipMM_Rmean (window = 2)
# 115 = precipMM_Rmin  (window = 2)
# 116 = precipMM_Rmax  (window = 2)
# 117 = precipMM_Rmean (window = 3)
# 118 = precipMM_Rmin  (window = 3)
# 119 = precipMM_Rmax  (window = 3)
# 120 = precipMM_Rmean (window = 4)
# 121 = precipMM_Rmin  (window = 4)
# 122 = precipMM_Rmax  (window = 4)
# 123 = precipMM_Rmean (window = 5)
# 124 = precipMM_Rmin  (window = 5)
# 125 = precipMM_Rmax  (window = 5)
# 126 = precipMM_Rmean (window = 6)
# 127 = precipMM_Rmin  (window = 6)
# 128 = precipMM_Rmax  (window = 6)
# 132 = precipMM_Rmean (window = 8)
# 133 = precipMM_Rmin  (window = 8)
# 134 = precipMM_Rmax  (window = 8)
# 135 = precipMM_Rmean (window = 9)
# 136 = precipMM_Rmin  (window = 9)
# 137 = precipMM_Rmax  (window = 9)
# 142 = humidity_Rmean (window = 2)
# 143 = humidity_Rmin  (window = 2)
# 144 = humidity_Rmax  (window = 2)
# 145 = humidity_Rmean (window = 3)
# 146 = humidity_Rmin  (window = 3)
# 147 = humidity_Rmax  (window = 3)
# 148 = humidity_Rmean (window = 4)
# 149 = humidity_Rmin  (window = 4)
# 150 = humidity_Rmax  (window = 4)
# 151 = humidity_Rmean (window = 5)
# 152 = humidity_Rmin  (window = 5)
# 153 = humidity_Rmax  (window = 5)
# 154 = humidity_Rmean (window = 6)
# 155 = humidity_Rmin  (window = 6)
# 156 = humidity_Rmax  (window = 6)
# 160 = humidity_Rmean (window = 8)
# 161 = humidity_Rmin  (window = 8)
# 162 = humidity_Rmax  (window = 8)
# 163 = humidity_Rmean (window = 9)
# 164 = humidity_Rmin  (window = 9)
# 165 = humidity_Rmax  (window = 9)
# 170 = visibility_Rmean (window = 2)
# 171 = visibility_Rmin  (window = 2)
# 172 = visibility_Rmax  (window = 2)
# 173 = visibility_Rmean (window = 3)
# 174 = visibility_Rmin  (window = 3)
# 175 = visibility_Rmax  (window = 3)
# 176 = visibility_Rmean (window = 4)
# 177 = visibility_Rmin  (window = 4)
# 178 = visibility_Rmax  (window = 4)
# 179 = visibility_Rmean (window = 5)
# 180 = visibility_Rmin  (window = 5)
# 181 = visibility_Rmax  (window = 5)
# 182 = visibility_Rmean (window = 6)
# 183 = visibility_Rmin  (window = 6)
# 184 = visibility_Rmax  (window = 6)
# 188 = visibility_Rmean (window = 8)
# 189 = visibility_Rmin  (window = 8)
# 190 = visibility_Rmax  (window = 8)
# 191 = visibility_Rmean (window = 9)
# 192 = visibility_Rmin  (window = 9)
# 193 = visibility_Rmax  (window = 9)
# 198 = pressure_Rmean (window = 2)
# 199 = pressure_Rmin  (window = 2)
# 200 = pressure_Rmax  (window = 2)
# 201 = pressure_Rmean (window = 3)
# 202 = pressure_Rmin  (window = 3)
# 203 = pressure_Rmax  (window = 3)
# 204 = pressure_Rmean (window = 4)
# 205 = pressure_Rmin  (window = 4)
# 206 = pressure_Rmax  (window = 4)
# 207 = pressure_Rmean (window = 5)
# 208 = pressure_Rmin  (window = 5)
# 209 = pressure_Rmax  (window = 5)
# 210 = pressure_Rmean (window = 6)
# 211 = pressure_Rmin  (window = 6)
# 212 = pressure_Rmax  (window = 6)
# 216 = pressure_Rmean (window = 8)
# 217 = pressure_Rmin  (window = 8)
# 218 = pressure_Rmax  (window = 8)
# 219 = pressure_Rmean (window = 9)
# 220 = pressure_Rmin  (window = 9)
# 221 = pressure_Rmax  (window = 9)
# 226 = cloudcover_Rmean (window = 2)
# 227 = cloudcover_Rmin  (window = 2)
# 228 = cloudcover_Rmax  (window = 2)
# 229 = cloudcover_Rmean (window = 3)
# 230 = cloudcover_Rmin  (window = 3)
# 231 = cloudcover_Rmax  (window = 3)
# 232 = cloudcover_Rmean (window = 4)
# 233 = cloudcover_Rmin  (window = 4)
# 234 = cloudcover_Rmax  (window = 4)
# 235 = cloudcover_Rmean (window = 5)
# 236 = cloudcover_Rmin  (window = 5)
# 237 = cloudcover_Rmax  (window = 5)
# 238 = cloudcover_Rmean (window = 6)
# 239 = cloudcover_Rmin  (window = 6)
# 240 = cloudcover_Rmax  (window = 6)
# 244 = cloudcover_Rmean (window = 8)
# 245 = cloudcover_Rmin  (window = 8)
# 246 = cloudcover_Rmax  (window = 8)
# 247 = cloudcover_Rmean (window = 9)
# 248 = cloudcover_Rmin  (window = 9)
# 249 = cloudcover_Rmax  (window = 9)
# 254 = dewPointC_Rmean (window = 2)
# 255 = dewPointC_Rmin  (window = 2)
# 256 = dewPointC_Rmax  (window = 2)
# 257 = dewPointC_Rmean (window = 3)
# 258 = dewPointC_Rmin  (window = 3)
# 259 = dewPointC_Rmax  (window = 3)
# 260 = dewPointC_Rmean (window = 4)
# 261 = dewPointC_Rmin  (window = 4)
# 262 = dewPointC_Rmax  (window = 4)
# 263 = dewPointC_Rmean (window = 5)
# 264 = dewPointC_Rmin  (window = 5)
# 265 = dewPointC_Rmax  (window = 5)
# 266 = dewPointC_Rmean (window = 6)
# 267 = dewPointC_Rmin  (window = 6)
# 268 = dewPointC_Rmax  (window = 6)
# 272 = dewPointC_Rmean (window = 8)
# 273 = dewPointC_Rmin  (window = 8)
# 274 = dewPointC_Rmax  (window = 8)
# 275 = dewPointC_Rmean (window = 9)
# 276 = dewPointC_Rmin  (window = 9)
# 277 = dewPointC_Rmax  (window = 9)
# 282 = windGustKmph_Rmean (window = 2)
# 283 = windGustKmph_Rmin  (window = 2)
# 284 = windGustKmph_Rmax  (window = 2)
# 285 = windGustKmph_Rmean (window = 3)
# 286 = windGustKmph_Rmin  (window = 3)
# 287 = windGustKmph_Rmax  (window = 3)
# 288 = windGustKmph_Rmean (window = 4)
# 289 = windGustKmph_Rmin  (window = 4)
# 290 = windGustKmph_Rmax  (window = 4)
# 291 = windGustKmph_Rmean (window = 5)
# 292 = windGustKmph_Rmin  (window = 5)
# 293 = windGustKmph_Rmax  (window = 5)
# 294 = windGustKmph_Rmean (window = 6)
# 295 = windGustKmph_Rmin  (window = 6)
# 296 = windGustKmph_Rmax  (window = 6)
# 300 = windGustKmph_Rmean (window = 8)
# 301 = windGustKmph_Rmin  (window = 8)
# 302 = windGustKmph_Rmax  (window = 8)
# 303 = windGustKmph_Rmean (window = 9)
# 304 = windGustKmph_Rmin  (window = 9)
# 305 = windGustKmph_Rmax  (window = 9)
# exporting eng_win7_wwo_Taft Ave._2015
# exported eng_win7_wwo_Taft Ave._2015
#
#
# ['Unnamed', 'window = 2', 'window = 3', 'window = 4', 'window = 5', 'window = 6', 'window = 7', 'window = 9']
# 13 = Unnamed: 13
# 14 = Unnamed: 14
# 15 = Unnamed: 15
# 16 = Unnamed: 16
# 17 = Unnamed: 17
# 18 = Unnamed: 18
# 19 = Unnamed: 19
# 20 = Unnamed: 20
# 21 = Unnamed: 21
# 22 = Unnamed: 22
# 23 = Unnamed: 23
# 24 = Unnamed: 24
# 25 = Unnamed: 25
# 30 = tempC_Rmean (window = 2)
# 31 = tempC_Rmin  (window = 2)
# 32 = tempC_Rmax  (window = 2)
# 33 = tempC_Rmean (window = 3)
# 34 = tempC_Rmin  (window = 3)
# 35 = tempC_Rmax  (window = 3)
# 36 = tempC_Rmean (window = 4)
# 37 = tempC_Rmin  (window = 4)
# 38 = tempC_Rmax  (window = 4)
# 39 = tempC_Rmean (window = 5)
# 40 = tempC_Rmin  (window = 5)
# 41 = tempC_Rmax  (window = 5)
# 42 = tempC_Rmean (window = 6)
# 43 = tempC_Rmin  (window = 6)
# 44 = tempC_Rmax  (window = 6)
# 45 = tempC_Rmean (window = 7)
# 46 = tempC_Rmin  (window = 7)
# 47 = tempC_Rmax  (window = 7)
# 51 = tempC_Rmean (window = 9)
# 52 = tempC_Rmin  (window = 9)
# 53 = tempC_Rmax  (window = 9)
# 58 = windspeedKmph_Rmean (window = 2)
# 59 = windspeedKmph_Rmin  (window = 2)
# 60 = windspeedKmph_Rmax  (window = 2)
# 61 = windspeedKmph_Rmean (window = 3)
# 62 = windspeedKmph_Rmin  (window = 3)
# 63 = windspeedKmph_Rmax  (window = 3)
# 64 = windspeedKmph_Rmean (window = 4)
# 65 = windspeedKmph_Rmin  (window = 4)
# 66 = windspeedKmph_Rmax  (window = 4)
# 67 = windspeedKmph_Rmean (window = 5)
# 68 = windspeedKmph_Rmin  (window = 5)
# 69 = windspeedKmph_Rmax  (window = 5)
# 70 = windspeedKmph_Rmean (window = 6)
# 71 = windspeedKmph_Rmin  (window = 6)
# 72 = windspeedKmph_Rmax  (window = 6)
# 73 = windspeedKmph_Rmean (window = 7)
# 74 = windspeedKmph_Rmin  (window = 7)
# 75 = windspeedKmph_Rmax  (window = 7)
# 79 = windspeedKmph_Rmean (window = 9)
# 80 = windspeedKmph_Rmin  (window = 9)
# 81 = windspeedKmph_Rmax  (window = 9)
# 86 = cond_Rmean (window = 2)
# 87 = cond_Rmin  (window = 2)
# 88 = cond_Rmax  (window = 2)
# 89 = cond_Rmean (window = 3)
# 90 = cond_Rmin  (window = 3)
# 91 = cond_Rmax  (window = 3)
# 92 = cond_Rmean (window = 4)
# 93 = cond_Rmin  (window = 4)
# 94 = cond_Rmax  (window = 4)
# 95 = cond_Rmean (window = 5)
# 96 = cond_Rmin  (window = 5)
# 97 = cond_Rmax  (window = 5)
# 98 = cond_Rmean (window = 6)
# 99 = cond_Rmin  (window = 6)
# 100 = cond_Rmax  (window = 6)
# 101 = cond_Rmean (window = 7)
# 102 = cond_Rmin  (window = 7)
# 103 = cond_Rmax  (window = 7)
# 107 = cond_Rmean (window = 9)
# 108 = cond_Rmin  (window = 9)
# 109 = cond_Rmax  (window = 9)
# 114 = precipMM_Rmean (window = 2)
# 115 = precipMM_Rmin  (window = 2)
# 116 = precipMM_Rmax  (window = 2)
# 117 = precipMM_Rmean (window = 3)
# 118 = precipMM_Rmin  (window = 3)
# 119 = precipMM_Rmax  (window = 3)
# 120 = precipMM_Rmean (window = 4)
# 121 = precipMM_Rmin  (window = 4)
# 122 = precipMM_Rmax  (window = 4)
# 123 = precipMM_Rmean (window = 5)
# 124 = precipMM_Rmin  (window = 5)
# 125 = precipMM_Rmax  (window = 5)
# 126 = precipMM_Rmean (window = 6)
# 127 = precipMM_Rmin  (window = 6)
# 128 = precipMM_Rmax  (window = 6)
# 129 = precipMM_Rmean (window = 7)
# 130 = precipMM_Rmin  (window = 7)
# 131 = precipMM_Rmax  (window = 7)
# 135 = precipMM_Rmean (window = 9)
# 136 = precipMM_Rmin  (window = 9)
# 137 = precipMM_Rmax  (window = 9)
# 142 = humidity_Rmean (window = 2)
# 143 = humidity_Rmin  (window = 2)
# 144 = humidity_Rmax  (window = 2)
# 145 = humidity_Rmean (window = 3)
# 146 = humidity_Rmin  (window = 3)
# 147 = humidity_Rmax  (window = 3)
# 148 = humidity_Rmean (window = 4)
# 149 = humidity_Rmin  (window = 4)
# 150 = humidity_Rmax  (window = 4)
# 151 = humidity_Rmean (window = 5)
# 152 = humidity_Rmin  (window = 5)
# 153 = humidity_Rmax  (window = 5)
# 154 = humidity_Rmean (window = 6)
# 155 = humidity_Rmin  (window = 6)
# 156 = humidity_Rmax  (window = 6)
# 157 = humidity_Rmean (window = 7)
# 158 = humidity_Rmin  (window = 7)
# 159 = humidity_Rmax  (window = 7)
# 163 = humidity_Rmean (window = 9)
# 164 = humidity_Rmin  (window = 9)
# 165 = humidity_Rmax  (window = 9)
# 170 = visibility_Rmean (window = 2)
# 171 = visibility_Rmin  (window = 2)
# 172 = visibility_Rmax  (window = 2)
# 173 = visibility_Rmean (window = 3)
# 174 = visibility_Rmin  (window = 3)
# 175 = visibility_Rmax  (window = 3)
# 176 = visibility_Rmean (window = 4)
# 177 = visibility_Rmin  (window = 4)
# 178 = visibility_Rmax  (window = 4)
# 179 = visibility_Rmean (window = 5)
# 180 = visibility_Rmin  (window = 5)
# 181 = visibility_Rmax  (window = 5)
# 182 = visibility_Rmean (window = 6)
# 183 = visibility_Rmin  (window = 6)
# 184 = visibility_Rmax  (window = 6)
# 185 = visibility_Rmean (window = 7)
# 186 = visibility_Rmin  (window = 7)
# 187 = visibility_Rmax  (window = 7)
# 191 = visibility_Rmean (window = 9)
# 192 = visibility_Rmin  (window = 9)
# 193 = visibility_Rmax  (window = 9)
# 198 = pressure_Rmean (window = 2)
# 199 = pressure_Rmin  (window = 2)
# 200 = pressure_Rmax  (window = 2)
# 201 = pressure_Rmean (window = 3)
# 202 = pressure_Rmin  (window = 3)
# 203 = pressure_Rmax  (window = 3)
# 204 = pressure_Rmean (window = 4)
# 205 = pressure_Rmin  (window = 4)
# 206 = pressure_Rmax  (window = 4)
# 207 = pressure_Rmean (window = 5)
# 208 = pressure_Rmin  (window = 5)
# 209 = pressure_Rmax  (window = 5)
# 210 = pressure_Rmean (window = 6)
# 211 = pressure_Rmin  (window = 6)
# 212 = pressure_Rmax  (window = 6)
# 213 = pressure_Rmean (window = 7)
# 214 = pressure_Rmin  (window = 7)
# 215 = pressure_Rmax  (window = 7)
# 219 = pressure_Rmean (window = 9)
# 220 = pressure_Rmin  (window = 9)
# 221 = pressure_Rmax  (window = 9)
# 226 = cloudcover_Rmean (window = 2)
# 227 = cloudcover_Rmin  (window = 2)
# 228 = cloudcover_Rmax  (window = 2)
# 229 = cloudcover_Rmean (window = 3)
# 230 = cloudcover_Rmin  (window = 3)
# 231 = cloudcover_Rmax  (window = 3)
# 232 = cloudcover_Rmean (window = 4)
# 233 = cloudcover_Rmin  (window = 4)
# 234 = cloudcover_Rmax  (window = 4)
# 235 = cloudcover_Rmean (window = 5)
# 236 = cloudcover_Rmin  (window = 5)
# 237 = cloudcover_Rmax  (window = 5)
# 238 = cloudcover_Rmean (window = 6)
# 239 = cloudcover_Rmin  (window = 6)
# 240 = cloudcover_Rmax  (window = 6)
# 241 = cloudcover_Rmean (window = 7)
# 242 = cloudcover_Rmin  (window = 7)
# 243 = cloudcover_Rmax  (window = 7)
# 247 = cloudcover_Rmean (window = 9)
# 248 = cloudcover_Rmin  (window = 9)
# 249 = cloudcover_Rmax  (window = 9)
# 254 = dewPointC_Rmean (window = 2)
# 255 = dewPointC_Rmin  (window = 2)
# 256 = dewPointC_Rmax  (window = 2)
# 257 = dewPointC_Rmean (window = 3)
# 258 = dewPointC_Rmin  (window = 3)
# 259 = dewPointC_Rmax  (window = 3)
# 260 = dewPointC_Rmean (window = 4)
# 261 = dewPointC_Rmin  (window = 4)
# 262 = dewPointC_Rmax  (window = 4)
# 263 = dewPointC_Rmean (window = 5)
# 264 = dewPointC_Rmin  (window = 5)
# 265 = dewPointC_Rmax  (window = 5)
# 266 = dewPointC_Rmean (window = 6)
# 267 = dewPointC_Rmin  (window = 6)
# 268 = dewPointC_Rmax  (window = 6)
# 269 = dewPointC_Rmean (window = 7)
# 270 = dewPointC_Rmin  (window = 7)
# 271 = dewPointC_Rmax  (window = 7)
# 275 = dewPointC_Rmean (window = 9)
# 276 = dewPointC_Rmin  (window = 9)
# 277 = dewPointC_Rmax  (window = 9)
# 282 = windGustKmph_Rmean (window = 2)
# 283 = windGustKmph_Rmin  (window = 2)
# 284 = windGustKmph_Rmax  (window = 2)
# 285 = windGustKmph_Rmean (window = 3)
# 286 = windGustKmph_Rmin  (window = 3)
# 287 = windGustKmph_Rmax  (window = 3)
# 288 = windGustKmph_Rmean (window = 4)
# 289 = windGustKmph_Rmin  (window = 4)
# 290 = windGustKmph_Rmax  (window = 4)
# 291 = windGustKmph_Rmean (window = 5)
# 292 = windGustKmph_Rmin  (window = 5)
# 293 = windGustKmph_Rmax  (window = 5)
# 294 = windGustKmph_Rmean (window = 6)
# 295 = windGustKmph_Rmin  (window = 6)
# 296 = windGustKmph_Rmax  (window = 6)
# 297 = windGustKmph_Rmean (window = 7)
# 298 = windGustKmph_Rmin  (window = 7)
# 299 = windGustKmph_Rmax  (window = 7)
# 303 = windGustKmph_Rmean (window = 9)
# 304 = windGustKmph_Rmin  (window = 9)
# 305 = windGustKmph_Rmax  (window = 9)
# exporting eng_win8_wwo_Taft Ave._2015
# exported eng_win8_wwo_Taft Ave._2015
#
#
# ['Unnamed', 'window = 2', 'window = 3', 'window = 4', 'window = 5', 'window = 6', 'window = 7', 'window = 8']
# 13 = Unnamed: 13
# 14 = Unnamed: 14
# 15 = Unnamed: 15
# 16 = Unnamed: 16
# 17 = Unnamed: 17
# 18 = Unnamed: 18
# 19 = Unnamed: 19
# 20 = Unnamed: 20
# 21 = Unnamed: 21
# 22 = Unnamed: 22
# 23 = Unnamed: 23
# 24 = Unnamed: 24
# 25 = Unnamed: 25
# 30 = tempC_Rmean (window = 2)
# 31 = tempC_Rmin  (window = 2)
# 32 = tempC_Rmax  (window = 2)
# 33 = tempC_Rmean (window = 3)
# 34 = tempC_Rmin  (window = 3)
# 35 = tempC_Rmax  (window = 3)
# 36 = tempC_Rmean (window = 4)
# 37 = tempC_Rmin  (window = 4)
# 38 = tempC_Rmax  (window = 4)
# 39 = tempC_Rmean (window = 5)
# 40 = tempC_Rmin  (window = 5)
# 41 = tempC_Rmax  (window = 5)
# 42 = tempC_Rmean (window = 6)
# 43 = tempC_Rmin  (window = 6)
# 44 = tempC_Rmax  (window = 6)
# 45 = tempC_Rmean (window = 7)
# 46 = tempC_Rmin  (window = 7)
# 47 = tempC_Rmax  (window = 7)
# 48 = tempC_Rmean (window = 8)
# 49 = tempC_Rmin  (window = 8)
# 50 = tempC_Rmax  (window = 8)
# 58 = windspeedKmph_Rmean (window = 2)
# 59 = windspeedKmph_Rmin  (window = 2)
# 60 = windspeedKmph_Rmax  (window = 2)
# 61 = windspeedKmph_Rmean (window = 3)
# 62 = windspeedKmph_Rmin  (window = 3)
# 63 = windspeedKmph_Rmax  (window = 3)
# 64 = windspeedKmph_Rmean (window = 4)
# 65 = windspeedKmph_Rmin  (window = 4)
# 66 = windspeedKmph_Rmax  (window = 4)
# 67 = windspeedKmph_Rmean (window = 5)
# 68 = windspeedKmph_Rmin  (window = 5)
# 69 = windspeedKmph_Rmax  (window = 5)
# 70 = windspeedKmph_Rmean (window = 6)
# 71 = windspeedKmph_Rmin  (window = 6)
# 72 = windspeedKmph_Rmax  (window = 6)
# 73 = windspeedKmph_Rmean (window = 7)
# 74 = windspeedKmph_Rmin  (window = 7)
# 75 = windspeedKmph_Rmax  (window = 7)
# 76 = windspeedKmph_Rmean (window = 8)
# 77 = windspeedKmph_Rmin  (window = 8)
# 78 = windspeedKmph_Rmax  (window = 8)
# 86 = cond_Rmean (window = 2)
# 87 = cond_Rmin  (window = 2)
# 88 = cond_Rmax  (window = 2)
# 89 = cond_Rmean (window = 3)
# 90 = cond_Rmin  (window = 3)
# 91 = cond_Rmax  (window = 3)
# 92 = cond_Rmean (window = 4)
# 93 = cond_Rmin  (window = 4)
# 94 = cond_Rmax  (window = 4)
# 95 = cond_Rmean (window = 5)
# 96 = cond_Rmin  (window = 5)
# 97 = cond_Rmax  (window = 5)
# 98 = cond_Rmean (window = 6)
# 99 = cond_Rmin  (window = 6)
# 100 = cond_Rmax  (window = 6)
# 101 = cond_Rmean (window = 7)
# 102 = cond_Rmin  (window = 7)
# 103 = cond_Rmax  (window = 7)
# 104 = cond_Rmean (window = 8)
# 105 = cond_Rmin  (window = 8)
# 106 = cond_Rmax  (window = 8)
# 114 = precipMM_Rmean (window = 2)
# 115 = precipMM_Rmin  (window = 2)
# 116 = precipMM_Rmax  (window = 2)
# 117 = precipMM_Rmean (window = 3)
# 118 = precipMM_Rmin  (window = 3)
# 119 = precipMM_Rmax  (window = 3)
# 120 = precipMM_Rmean (window = 4)
# 121 = precipMM_Rmin  (window = 4)
# 122 = precipMM_Rmax  (window = 4)
# 123 = precipMM_Rmean (window = 5)
# 124 = precipMM_Rmin  (window = 5)
# 125 = precipMM_Rmax  (window = 5)
# 126 = precipMM_Rmean (window = 6)
# 127 = precipMM_Rmin  (window = 6)
# 128 = precipMM_Rmax  (window = 6)
# 129 = precipMM_Rmean (window = 7)
# 130 = precipMM_Rmin  (window = 7)
# 131 = precipMM_Rmax  (window = 7)
# 132 = precipMM_Rmean (window = 8)
# 133 = precipMM_Rmin  (window = 8)
# 134 = precipMM_Rmax  (window = 8)
# 142 = humidity_Rmean (window = 2)
# 143 = humidity_Rmin  (window = 2)
# 144 = humidity_Rmax  (window = 2)
# 145 = humidity_Rmean (window = 3)
# 146 = humidity_Rmin  (window = 3)
# 147 = humidity_Rmax  (window = 3)
# 148 = humidity_Rmean (window = 4)
# 149 = humidity_Rmin  (window = 4)
# 150 = humidity_Rmax  (window = 4)
# 151 = humidity_Rmean (window = 5)
# 152 = humidity_Rmin  (window = 5)
# 153 = humidity_Rmax  (window = 5)
# 154 = humidity_Rmean (window = 6)
# 155 = humidity_Rmin  (window = 6)
# 156 = humidity_Rmax  (window = 6)
# 157 = humidity_Rmean (window = 7)
# 158 = humidity_Rmin  (window = 7)
# 159 = humidity_Rmax  (window = 7)
# 160 = humidity_Rmean (window = 8)
# 161 = humidity_Rmin  (window = 8)
# 162 = humidity_Rmax  (window = 8)
# 170 = visibility_Rmean (window = 2)
# 171 = visibility_Rmin  (window = 2)
# 172 = visibility_Rmax  (window = 2)
# 173 = visibility_Rmean (window = 3)
# 174 = visibility_Rmin  (window = 3)
# 175 = visibility_Rmax  (window = 3)
# 176 = visibility_Rmean (window = 4)
# 177 = visibility_Rmin  (window = 4)
# 178 = visibility_Rmax  (window = 4)
# 179 = visibility_Rmean (window = 5)
# 180 = visibility_Rmin  (window = 5)
# 181 = visibility_Rmax  (window = 5)
# 182 = visibility_Rmean (window = 6)
# 183 = visibility_Rmin  (window = 6)
# 184 = visibility_Rmax  (window = 6)
# 185 = visibility_Rmean (window = 7)
# 186 = visibility_Rmin  (window = 7)
# 187 = visibility_Rmax  (window = 7)
# 188 = visibility_Rmean (window = 8)
# 189 = visibility_Rmin  (window = 8)
# 190 = visibility_Rmax  (window = 8)
# 198 = pressure_Rmean (window = 2)
# 199 = pressure_Rmin  (window = 2)
# 200 = pressure_Rmax  (window = 2)
# 201 = pressure_Rmean (window = 3)
# 202 = pressure_Rmin  (window = 3)
# 203 = pressure_Rmax  (window = 3)
# 204 = pressure_Rmean (window = 4)
# 205 = pressure_Rmin  (window = 4)
# 206 = pressure_Rmax  (window = 4)
# 207 = pressure_Rmean (window = 5)
# 208 = pressure_Rmin  (window = 5)
# 209 = pressure_Rmax  (window = 5)
# 210 = pressure_Rmean (window = 6)
# 211 = pressure_Rmin  (window = 6)
# 212 = pressure_Rmax  (window = 6)
# 213 = pressure_Rmean (window = 7)
# 214 = pressure_Rmin  (window = 7)
# 215 = pressure_Rmax  (window = 7)
# 216 = pressure_Rmean (window = 8)
# 217 = pressure_Rmin  (window = 8)
# 218 = pressure_Rmax  (window = 8)
# 226 = cloudcover_Rmean (window = 2)
# 227 = cloudcover_Rmin  (window = 2)
# 228 = cloudcover_Rmax  (window = 2)
# 229 = cloudcover_Rmean (window = 3)
# 230 = cloudcover_Rmin  (window = 3)
# 231 = cloudcover_Rmax  (window = 3)
# 232 = cloudcover_Rmean (window = 4)
# 233 = cloudcover_Rmin  (window = 4)
# 234 = cloudcover_Rmax  (window = 4)
# 235 = cloudcover_Rmean (window = 5)
# 236 = cloudcover_Rmin  (window = 5)
# 237 = cloudcover_Rmax  (window = 5)
# 238 = cloudcover_Rmean (window = 6)
# 239 = cloudcover_Rmin  (window = 6)
# 240 = cloudcover_Rmax  (window = 6)
# 241 = cloudcover_Rmean (window = 7)
# 242 = cloudcover_Rmin  (window = 7)
# 243 = cloudcover_Rmax  (window = 7)
# 244 = cloudcover_Rmean (window = 8)
# 245 = cloudcover_Rmin  (window = 8)
# 246 = cloudcover_Rmax  (window = 8)
# 254 = dewPointC_Rmean (window = 2)
# 255 = dewPointC_Rmin  (window = 2)
# 256 = dewPointC_Rmax  (window = 2)
# 257 = dewPointC_Rmean (window = 3)
# 258 = dewPointC_Rmin  (window = 3)
# 259 = dewPointC_Rmax  (window = 3)
# 260 = dewPointC_Rmean (window = 4)
# 261 = dewPointC_Rmin  (window = 4)
# 262 = dewPointC_Rmax  (window = 4)
# 263 = dewPointC_Rmean (window = 5)
# 264 = dewPointC_Rmin  (window = 5)
# 265 = dewPointC_Rmax  (window = 5)
# 266 = dewPointC_Rmean (window = 6)
# 267 = dewPointC_Rmin  (window = 6)
# 268 = dewPointC_Rmax  (window = 6)
# 269 = dewPointC_Rmean (window = 7)
# 270 = dewPointC_Rmin  (window = 7)
# 271 = dewPointC_Rmax  (window = 7)
# 272 = dewPointC_Rmean (window = 8)
# 273 = dewPointC_Rmin  (window = 8)
# 274 = dewPointC_Rmax  (window = 8)
# 282 = windGustKmph_Rmean (window = 2)
# 283 = windGustKmph_Rmin  (window = 2)
# 284 = windGustKmph_Rmax  (window = 2)
# 285 = windGustKmph_Rmean (window = 3)
# 286 = windGustKmph_Rmin  (window = 3)
# 287 = windGustKmph_Rmax  (window = 3)
# 288 = windGustKmph_Rmean (window = 4)
# 289 = windGustKmph_Rmin  (window = 4)
# 290 = windGustKmph_Rmax  (window = 4)
# 291 = windGustKmph_Rmean (window = 5)
# 292 = windGustKmph_Rmin  (window = 5)
# 293 = windGustKmph_Rmax  (window = 5)
# 294 = windGustKmph_Rmean (window = 6)
# 295 = windGustKmph_Rmin  (window = 6)
# 296 = windGustKmph_Rmax  (window = 6)
# 297 = windGustKmph_Rmean (window = 7)
# 298 = windGustKmph_Rmin  (window = 7)
# 299 = windGustKmph_Rmax  (window = 7)
# 300 = windGustKmph_Rmean (window = 8)
# 301 = windGustKmph_Rmin  (window = 8)
# 302 = windGustKmph_Rmax  (window = 8)
# exporting eng_win9_wwo_Taft Ave._2015
# exported eng_win9_wwo_Taft Ave._2015
#
#
# --END--
