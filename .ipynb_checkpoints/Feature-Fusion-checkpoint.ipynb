# %% [markdown]
# ## Import Necessary Packages

# %%
import numpy as np
import pandas as pd
import datetime

np.random.seed(1337)  # for reproducibility
from sklearn.model_selection import train_test_split
from sklearn.metrics.classification import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.regression import r2_score, mean_squared_error, mean_absolute_error

from dbn.tensorflow import SupervisedDBNRegression

# %% [markdown]
# ## Define Model Settings

# %%
RBM_EPOCHS = 5
DBN_EPOCHS = 150
RBM_LEARNING_RATE = 0.01
DBN_LEARNING_RATE = 0.01
HIDDEN_LAYER_STRUCT = [20, 50, 100]
ACTIVE_FUNC = 'relu'
BATCH_SIZE = 28

# %% [markdown]
# ## Define Directory, Road, and Year

# %%
# Read the dataset
ROAD = "Vicente Cruz"
YEAR = "2015"
EXT = ".csv"
DATASET_DIVISION = "seasonWet"
DIR = "../../../datasets/Thesis Datasets/"

'''''''Training dataset'''''''
WP = True
weatherDT = "recon_weather" #orig_weather   recon_weather
trafficDT = "recon_traffic" #orig_traffic   recon_traffic

traffic_featureEngineering = "Rolling and Expanding" #Rolling   Expanding   Rolling and Expanding
weather_featureEngineering = "Rolling and Expanding" #Rolling   Expanding   Rolling and Expanding
traffic_featuresNeeded = ['statusN']
weather_featuresNeeded = ['heatIndexC', 'windspeedMiles', 'dewPointC'] #Most correlated without redundant
# weather_featuresNeeded = ['tempC', 'windspeedMiles', 'humidity', 'heatIndexC', #All corr > 0.1
#                           'dewPointC','windChillC', 'feelsLikeC']
# weather_featuresNeeded = ['tempC', 'windspeedMiles', 'precipMM', 'visibility', #All Features
#                 'humidity', 'pressure', 'cloudcover', 'heatIndexC',
#                 'dewPointC', 'windChillC', 'windGustMiles', 'feelsLikeC']

TRAFFIC_ROLLING_WINDOW = 3
TRAFFIC_EXPANDING_WINDOW = 3
WEATHER_ROLLING_WINDOW = 3
WEATHER_EXPANDING_WINDOW = 12
RECON_SHIFT = 96

# %%
RBM_EPOCHS = 5
DBN_EPOCHS = 150
RBM_LEARNING_RATE = 0.01
DBN_LEARNING_RATE = 0.01
HIDDEN_LAYER_STRUCT = [20, 50, 100]
ACTIVE_FUNC = 'relu'
BATCH_SIZE = 28

# %%
def addWorkingPeakFeatures(df):
    result_df = df.copy()

    # Converting the index as date
    result_df.index = pd.to_datetime(result_df.index)
    
    # Create column work_day
    result_df['work_day'] = ((result_df.index.dayofweek) < 5).astype(int)

    # Consider non-working holiday
    if DATASET_DIVISION is not "seasonWet":

        # Jan
        result_df.loc['2015-01-01', 'work_day'] = 0
        result_df.loc['2015-01-02', 'work_day'] = 0

        # Feb
        result_df.loc['2015-02-19', 'work_day'] = 0
        result_df.loc['2015-02-25', 'work_day'] = 0

        # Apr
        result_df.loc['2015-04-02', 'work_day'] = 0
        result_df.loc['2015-04-03', 'work_day'] = 0
        result_df.loc['2015-04-09', 'work_day'] = 0

        # May
        result_df.loc['2015-05-01', 'work_day'] = 0

    # Jun
    result_df.loc['2015-06-12', 'work_day'] = 0
    result_df.loc['2015-06-24', 'work_day'] = 0

    # Jul
    result_df.loc['2015-07-17', 'work_day'] = 0

    # Aug
    result_df.loc['2015-08-21', 'work_day'] = 0
    result_df.loc['2015-08-31', 'work_day'] = 0

    # Sep
    result_df.loc['2015-08-25', 'work_day'] = 0

    if DATASET_DIVISION is not "seasonWet":
        # Nov
        result_df.loc['2015-11-30', 'work_day'] = 0

        # Dec
        result_df.loc['2015-12-24', 'work_day'] = 0
        result_df.loc['2015-12-25', 'work_day'] = 0
        result_df.loc['2015-12-30', 'work_day'] = 0
        result_df.loc['2015-12-31', 'work_day'] = 0

    # Consider class suspension
    if DATASET_DIVISION is not "seasonWet":
        # Jan
        result_df.loc['2015-01-08', 'work_day'] = 0
        result_df.loc['2015-01-09', 'work_day'] = 0
        result_df.loc['2015-01-14', 'work_day'] = 0
        result_df.loc['2015-01-15', 'work_day'] = 0
        result_df.loc['2015-01-16', 'work_day'] = 0
        result_df.loc['2015-01-17', 'work_day'] = 0

    # Jul
    result_df.loc['2015-07-06', 'work_day'] = 0
    result_df.loc['2015-07-08', 'work_day'] = 0
    result_df.loc['2015-07-09', 'work_day'] = 0
    result_df.loc['2015-07-10', 'work_day'] = 0

    # Aug
    result_df.loc['2015-08-10', 'work_day'] = 0
    result_df.loc['2015-08-11', 'work_day'] = 0

    # Sep
    result_df.loc['2015-09-10', 'work_day'] = 0

    # Oct
    result_df.loc['2015-10-02', 'work_day'] = 0
    result_df.loc['2015-10-19', 'work_day'] = 0

    if DATASET_DIVISION is not "seasonWet":
        # Nov
        result_df.loc['2015-11-16', 'work_day'] = 0
        result_df.loc['2015-11-17', 'work_day'] = 0
        result_df.loc['2015-11-18', 'work_day'] = 0
        result_df.loc['2015-11-19', 'work_day'] = 0
        result_df.loc['2015-11-20', 'work_day'] = 0

        # Dec
        result_df.loc['2015-12-16', 'work_day'] = 0
        result_df.loc['2015-12-18', 'work_day'] = 0

    result_df['peak_hour'] = 0

    # Set morning peak hour

    start = datetime.time(7,0,0)
    end = datetime.time(10,0,0)

    result_df.loc[result_df.between_time(start, end).index, 'peak_hour'] = 1

    # Set afternoon peak hour

    start = datetime.time(16,0,0)
    end = datetime.time(19,0,0)

    result_df.loc[result_df.between_time(start, end).index, 'peak_hour'] = 1
    
    result_df
    
    return result_df

# %%
def reconstructDT(df, typeDataset='traffic', trafficFeatureNeeded=[]):
    result_df = df.copy()

    # Converting the index as date
    result_df.index = pd.to_datetime(result_df.index, format='%d/%m/%Y %H:%M')
    result_df['month'] = result_df.index.month
    result_df['year'] = result_df.index.month
    result_df['day'] = result_df.index.day
    result_df['hour'] = result_df.index.hour
    result_df['min'] = result_df.index.minute    
    result_df['dayOfWeek'] = result_df.index.dayofweek
    
    if typeDataset == 'traffic' or typeDataset == 'ff':
        for f in trafficFeatureNeeded:
            result_df[f + '_' + str(RECON_SHIFT)] = result_df[f].shift(RECON_SHIFT)    
            result_df[f + '_' + str(RECON_SHIFT)] = result_df[f].shift(RECON_SHIFT)
            
    result_df = result_df.iloc[96:, :]
    
    for f in range(len(result_df.columns)):
        result_df[result_df.columns[f]] = normalize(result_df[result_df.columns[f]])

    return result_df

def shiftDTForReconstructed(df):
    return df.iloc[shift:, :]

# %%
def getNeededFeatures(columns, arrFeaturesNeed=[], featureEngineering="Original"):
    to_remove = []
    if len(arrFeaturesNeed) == 0: #all features aren't needed
        return []
    else:
        if featureEngineering == "Original":
            compareTo = " "
        elif featureEngineering == "Rolling" or featureEngineering == "Expanding":
            compareTo = "_"
            
        for f in arrFeaturesNeed:
            for c in range(0, len(columns)):
                if (len(columns[c].split(compareTo)) <= 1 and featureEngineering != "Original"):
                    to_remove.append(c)
                if f not in columns[c].split(compareTo)[0] and columns[c].split(compareTo)[0] not in arrFeaturesNeed:
                    to_remove.append(c)
                        
    return to_remove

# %%
def normalize(data):
    y = pd.to_numeric(data)
    y = np.array(y.reshape(-1, 1))
    
    scaler = MinMaxScaler()
    y = scaler.fit_transform(y)
    y = y.reshape(1, -1)[0]
    return y

# %% [markdown]
# <br><br>
# ### Preparing Traffic Dataset

# %% [markdown]
# #### Importing Original Traffic (wo new features)

# %%
TRAFFIC_DIR = DIR + "mmda/"
TRAFFIC_FILENAME = "mmda_" + ROAD + "_" + YEAR + "_" + DATASET_DIVISION
orig_traffic = pd.read_csv(TRAFFIC_DIR + TRAFFIC_FILENAME + EXT, skipinitialspace=True)
orig_traffic = orig_traffic.fillna(0)

#Converting index to date and time, and removing 'dt' column
orig_traffic.index = pd.to_datetime(orig_traffic.dt, format='%d/%m/%Y %H:%M')
cols_to_remove = [0]
cols_to_remove = getNeededFeatures(orig_traffic.columns, traffic_featuresNeeded)
orig_traffic.drop(orig_traffic.columns[[cols_to_remove]], axis=1, inplace=True)
orig_traffic.head()
# Out:
#                       statusN
# dt
# 2015-06-01 00:00:00  0.908264
# 2015-06-01 00:15:00  0.909505
# 2015-06-01 00:30:00  0.910818
# 2015-06-01 00:45:00  0.912204
# 2015-06-01 01:00:00  0.913664

# %%
TRAFFIC_DIR = DIR + "mmda/Rolling/" + DATASET_DIVISION + "/"
TRAFFIC_FILENAME = "eng_win" + str(TRAFFIC_ROLLING_WINDOW) + "_mmda_" + ROAD + "_" + YEAR + "_" + DATASET_DIVISION
rolling_traffic = pd.read_csv(TRAFFIC_DIR + TRAFFIC_FILENAME + EXT, skipinitialspace=True)

cols_to_remove = [0, 1, 2]
cols_to_remove += getNeededFeatures(rolling_traffic.columns, orig_traffic.columns, "Rolling")

rolling_traffic.index = pd.to_datetime(rolling_traffic.dt, format='%Y-%m-%d %H:%M')

rolling_traffic.drop(rolling_traffic.columns[[cols_to_remove]], axis=1, inplace=True)

for f in range(len(rolling_traffic.columns)):
        rolling_traffic[rolling_traffic.columns[f]] = normalize(rolling_traffic[rolling_traffic.columns[f]])

rolling_traffic.head()
# Out:
# c:\users\ronnie nieva\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                      statusN_Rmean=3  statusN_Rmin=3  statusN_Rmax=3
# dt
# 2015-06-01 00:00:00         0.000000        0.000000        0.000000
# 2015-06-01 00:15:00         0.000000        0.000000        0.000000
# 2015-06-01 00:30:00         0.306162        0.000000        0.908264
# 2015-06-01 00:45:00         0.612742        0.000000        0.909505
# 2015-06-01 01:00:00         0.919765        0.929385        0.910818

# %%
TRAFFIC_DIR = DIR + "mmda/Expanding/" + DATASET_DIVISION + "/"
TRAFFIC_FILENAME = "eng_win" + str(TRAFFIC_EXPANDING_WINDOW) + "_mmda_" + ROAD + "_" + YEAR + "_" + DATASET_DIVISION
expanding_traffic = pd.read_csv(TRAFFIC_DIR + TRAFFIC_FILENAME + EXT, skipinitialspace=True)

cols_to_remove = [0, 1, 2]
cols_to_remove += getNeededFeatures(expanding_traffic.columns, ["statusN"], "Rolling")

expanding_traffic.index = pd.to_datetime(expanding_traffic.dt, format='%d/%m/%Y %H:%M')

expanding_traffic.drop(expanding_traffic.columns[[cols_to_remove]], axis=1, inplace=True)

for f in range(len(expanding_traffic.columns)):
        expanding_traffic[expanding_traffic.columns[f]] = normalize(expanding_traffic[expanding_traffic.columns[f]])

expanding_traffic.head()
# Out:
# c:\users\ronnie nieva\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                      statusN_Emin=3  statusN_Emax=3  statusN_Esum=3  \
# dt
# 2015-06-01 00:00:00        0.908264        0.907668        0.310353
# 2015-06-01 00:15:00        0.908264        0.908918        0.623355
# 2015-06-01 00:30:00        0.908264        0.910239        0.936808
# 2015-06-01 00:45:00        0.912204        0.911634        0.311709
# 2015-06-01 01:00:00        0.912204        0.913103        0.626142
#
#                      statusN_Emean=3
# dt
# 2015-06-01 00:00:00         0.907668
# 2015-06-01 00:15:00         0.908293
# 2015-06-01 00:30:00         0.908942
# 2015-06-01 00:45:00         0.911634
# 2015-06-01 01:00:00         0.912368

# %%
recon_traffic = reconstructDT(orig_traffic, 'traffic', ['statusN'])
recon_traffic.head()
# Out:
# c:\users\ronnie nieva\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\ronnie nieva\anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
#                       statusN  month  year       day      hour       min  \
# dt
# 2015-06-02 00:00:00  0.438567    0.0   0.0  0.033333  0.000000  0.000000
# 2015-06-02 00:15:00  0.555569    0.0   0.0  0.033333  0.000000  0.333333
# 2015-06-02 00:30:00  0.683338    0.0   0.0  0.033333  0.000000  0.666667
# 2015-06-02 00:45:00  0.795359    0.0   0.0  0.033333  0.000000  1.000000
# 2015-06-02 01:00:00  0.874074    0.0   0.0  0.033333  0.043478  0.000000
#
#                      dayOfWeek  statusN_96
# dt
# 2015-06-02 00:00:00   0.166667    0.908264
# 2015-06-02 00:15:00   0.166667    0.909505
# 2015-06-02 00:30:00   0.166667    0.910818
# 2015-06-02 00:45:00   0.166667    0.912204
# 2015-06-02 01:00:00   0.166667    0.913664

# %% [markdown]
# <br><br>
# ## Preparing Weather dataset

# %% [markdown]
# #### Importing Original Weather (wo new features)

# %%
WEATHER_DIR = DIR + "wwo/"
WEATHER_FILENAME = "wwo_" + ROAD + "_" + YEAR + "_" + DATASET_DIVISION

orig_weather = pd.read_csv(WEATHER_DIR + WEATHER_FILENAME + EXT, skipinitialspace=True)

cols_to_remove = [0]
cols_to_remove += getNeededFeatures(orig_weather.columns, arrFeaturesNeed=weather_featuresNeeded)

orig_weather.index = pd.to_datetime(orig_weather.dt, format='%d/%m/%Y %H:%M')
orig_weather.drop(orig_weather.columns[[cols_to_remove]], axis=1, inplace=True)
orig_weather.head()
# Out:
#                      windspeedMiles  heatIndexC  dewPointC
# dt
# 2015-06-01 00:00:00        0.107143     0.26087        0.5
# 2015-06-01 00:15:00        0.116071     0.26087        0.5
# 2015-06-01 00:30:00        0.125000     0.26087        0.5
# 2015-06-01 00:45:00        0.133929     0.26087        0.5
# 2015-06-01 01:00:00        0.142857     0.26087        0.5

# %% [markdown]
# #### Importing Weather with Rolling features (with only needed features)

# %%
WEATHER_DIR = DIR + "wwo/Rolling/" + DATASET_DIVISION + "/"
WEATHER_FILENAME = "eng_win" + str(WEATHER_ROLLING_WINDOW) + "_wwo_" + ROAD + "_" + YEAR + "_" + DATASET_DIVISION
rolling_weather = pd.read_csv(WEATHER_DIR + WEATHER_FILENAME + EXT, skipinitialspace=True)

cols_to_remove = []
cols_to_remove += getNeededFeatures(rolling_weather.columns, orig_weather.columns, featureEngineering="Rolling")
rolling_weather.index = pd.to_datetime(rolling_weather.dt, format='%Y-%m-%d %H:%M')

rolling_weather.drop(rolling_weather.columns[[cols_to_remove]], axis=1, inplace=True)

for f in range(len(rolling_weather.columns)):
        rolling_weather[rolling_weather.columns[f]] = normalize(rolling_weather[rolling_weather.columns[f]])

rolling_weather.head()
# Out:
# c:\users\ronnie nieva\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                      windspeedMiles_Rmean=3  heatIndexC_Rmean=3  \
# dt
# 2015-06-01 00:00:00                0.000000            0.000000
# 2015-06-01 00:15:00                0.000000            0.000000
# 2015-06-01 00:30:00                0.035714            0.087591
# 2015-06-01 00:45:00                0.074405            0.175182
# 2015-06-01 01:00:00                0.116071            0.262774
#
#                      dewPointC_Rmean=3  windspeedMiles_Rmin=3  \
# dt
# 2015-06-01 00:00:00           0.000000               0.000000
# 2015-06-01 00:15:00           0.000000               0.000000
# 2015-06-01 00:30:00           0.166667               0.000000
# 2015-06-01 00:45:00           0.333333               0.000000
# 2015-06-01 01:00:00           0.500000               0.107143
#
#                      heatIndexC_Rmin=3  dewPointC_Rmin=3  \
# dt
# 2015-06-01 00:00:00           0.000000               0.0
# 2015-06-01 00:15:00           0.000000               0.0
# 2015-06-01 00:30:00           0.000000               0.0
# 2015-06-01 00:45:00           0.000000               0.0
# 2015-06-01 01:00:00           0.263736               0.5
#
#                      windspeedMiles_Rmax=3  heatIndexC_Rmax=3  \
# dt
# 2015-06-01 00:00:00               0.000000            0.00000
# 2015-06-01 00:15:00               0.000000            0.00000
# 2015-06-01 00:30:00               0.107143            0.26087
# 2015-06-01 00:45:00               0.116071            0.26087
# 2015-06-01 01:00:00               0.125000            0.26087
#
#                      dewPointC_Rmax=3
# dt
# 2015-06-01 00:00:00               0.0
# 2015-06-01 00:15:00               0.0
# 2015-06-01 00:30:00               0.5
# 2015-06-01 00:45:00               0.5
# 2015-06-01 01:00:00               0.5

# %% [markdown]
# #### Importing Weather with Expanding features (with only needed features)

# %%
WEATHER_DIR = DIR + "wwo/Expanding/" + DATASET_DIVISION + "/"
WEATHER_FILENAME = "eng_win" + str(WEATHER_EXPANDING_WINDOW) + "_wwo_" + ROAD + "_" + YEAR + "_" + DATASET_DIVISION
expanding_weather = pd.read_csv(WEATHER_DIR + WEATHER_FILENAME + EXT, skipinitialspace=True)

cols_to_remove = []
cols_to_remove += getNeededFeatures(expanding_weather.columns, orig_weather.columns, featureEngineering="Rolling")
     
expanding_weather.index = pd.to_datetime(expanding_weather.dt, format='%d/%m/%Y %H:%M')

expanding_weather.drop(expanding_weather.columns[[cols_to_remove]], axis=1, inplace=True)

for f in range(len(expanding_weather.columns)):
        expanding_weather[expanding_weather.columns[f]] = normalize(expanding_weather[expanding_weather.columns[f]])

expanding_weather.head()
# Out:
# c:\users\ronnie nieva\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                      windspeedMiles_Emin=12  windspeedMiles_Emax=12  \
# dt
# 2015-06-01 00:00:00                0.107143                0.107143
# 2015-06-01 00:15:00                0.107143                0.116071
# 2015-06-01 00:30:00                0.107143                0.125000
# 2015-06-01 00:45:00                0.107143                0.133929
# 2015-06-01 01:00:00                0.107143                0.142857
#
#                      windspeedMiles_Esum=12  windspeedMiles_Emean=12  \
# dt
# 2015-06-01 00:00:00                0.008929                 0.107143
# 2015-06-01 00:15:00                0.018601                 0.111607
# 2015-06-01 00:30:00                0.029018                 0.116071
# 2015-06-01 00:45:00                0.040179                 0.120536
# 2015-06-01 01:00:00                0.052083                 0.125000
#
#                      heatIndexC_Emin=12  heatIndexC_Emax=12  \
# dt
# 2015-06-01 00:00:00             0.26087             0.26087
# 2015-06-01 00:15:00             0.26087             0.26087
# 2015-06-01 00:30:00             0.26087             0.26087
# 2015-06-01 00:45:00             0.26087             0.26087
# 2015-06-01 01:00:00             0.26087             0.26087
#
#                      heatIndexC_Esum=12  heatIndexC_Emean=12  \
# dt
# 2015-06-01 00:00:00            0.022989              0.26087
# 2015-06-01 00:15:00            0.045977              0.26087
# 2015-06-01 00:30:00            0.068966              0.26087
# 2015-06-01 00:45:00            0.091954              0.26087
# 2015-06-01 01:00:00            0.114943              0.26087
#
#                      dewPointC_Emin=12  dewPointC_Emax=12  dewPointC_Esum=12  \
# dt
# 2015-06-01 00:00:00                0.5                0.5           0.041667
# 2015-06-01 00:15:00                0.5                0.5           0.083333
# 2015-06-01 00:30:00                0.5                0.5           0.125000
# 2015-06-01 00:45:00                0.5                0.5           0.166667
# 2015-06-01 01:00:00                0.5                0.5           0.208333
#
#                      dewPointC_Emean=12
# dt
# 2015-06-01 00:00:00                 0.5
# 2015-06-01 00:15:00                 0.5
# 2015-06-01 00:30:00                 0.5
# 2015-06-01 00:45:00                 0.5
# 2015-06-01 01:00:00                 0.5

# %% [markdown]
# ### Merging datasets

# %% [markdown]
# #### Reconstructing Weather Input for recon_weather dataset

# %%
''''''' Do not touch below '''''''

if trafficDT == "orig_traffic":
    print("Adding orig_weather")
    arrDT = [orig_traffic, orig_weather]

elif trafficDT == "recon_traffic":
    arrDT = [recon_traffic, orig_weather.iloc[96:,:]]
    
if weather_featureEngineering == "Rolling":
    print("Adding Rolling - Weather")
    startIndex = np.absolute(len(arrDT[0])-len(rolling_weather))
    temp = rolling_weather.iloc[startIndex:, :]
    arrDT.append(temp)
    
elif weather_featureEngineering == "Expanding":
    print("Adding Expanding - Weather")
    startIndex = np.absolute(len(arrDT[0])-len(expanding_weather))
    temp = expanding_weather.iloc[startIndex:, :]
    arrDT.append(temp)
    
elif weather_featureEngineering == "Rolling and Expanding":
    print("Adding Rolling and Expanding - Weather")
    #Rolling
    startIndex = np.absolute(len(arrDT[0])-len(rolling_weather))
    temp = rolling_weather.iloc[startIndex:, :]
    arrDT.append(temp)
    #Expanding
    startIndex = np.absolute(len(arrDT[0])-len(expanding_weather))
    temp = expanding_weather.iloc[startIndex:, :]
    arrDT.append(temp)
    
if traffic_featureEngineering == "Rolling":
    print("Adding Rolling - Traffic")
    startIndex = np.absolute(len(arrDT[0])-len(rolling_traffic))
    temp = rolling_traffic.iloc[startIndex:, :]
    arrDT.append(temp)
    
elif traffic_featureEngineering == "Expanding":
    print("Adding Expanding - Traffic")
    startIndex = np.absolute(len(arrDT[0])-len(expanding_traffic))
    temp = expanding_traffic.iloc[startIndex:, :]
    arrDT.append(temp)
    
elif traffic_featureEngineering == "Rolling and Expanding":
    print("Adding Rolling and Expanding- Traffic")
    #Rolling
    startIndex = np.absolute(len(arrDT[0])-len(rolling_traffic))
    temp = rolling_traffic.iloc[startIndex:, :]
    arrDT.append(temp)
    #Expanding
    startIndex = np.absolute(len(arrDT[0])-len(expanding_traffic))
    temp = expanding_traffic.iloc[startIndex:, :]
    arrDT.append(temp)

merged_dataset = pd.concat(arrDT, axis=1)
merged_dataset.head()
# Out:
# Adding Rolling and Expanding - Weather
# Adding Rolling and Expanding- Traffic
#                       statusN  month  year       day      hour       min  \
# dt
# 2015-06-02 00:00:00  0.438567    0.0   0.0  0.033333  0.000000  0.000000
# 2015-06-02 00:15:00  0.555569    0.0   0.0  0.033333  0.000000  0.333333
# 2015-06-02 00:30:00  0.683338    0.0   0.0  0.033333  0.000000  0.666667
# 2015-06-02 00:45:00  0.795359    0.0   0.0  0.033333  0.000000  1.000000
# 2015-06-02 01:00:00  0.874074    0.0   0.0  0.033333  0.043478  0.000000
#
#                      dayOfWeek  statusN_96  windspeedMiles  heatIndexC  \
# dt
# 2015-06-02 00:00:00   0.166667    0.908264        0.178571    0.304348
# 2015-06-02 00:15:00   0.166667    0.909505        0.178571    0.293478
# 2015-06-02 00:30:00   0.166667    0.910818        0.178571    0.282609
# 2015-06-02 00:45:00   0.166667    0.912204        0.178571    0.271739
# 2015-06-02 01:00:00   0.166667    0.913664        0.178571    0.260870
#
#                           ...         dewPointC_Emax=12  dewPointC_Esum=12  \
# dt                        ...
# 2015-06-02 00:00:00       ...                     0.625           0.052083
# 2015-06-02 00:15:00       ...                     0.625           0.104167
# 2015-06-02 00:30:00       ...                     0.625           0.156250
# 2015-06-02 00:45:00       ...                     0.625           0.208333
# 2015-06-02 01:00:00       ...                     0.625           0.260417
#
#                      dewPointC_Emean=12  statusN_Rmean=3  statusN_Rmin=3  \
# dt
# 2015-06-02 00:00:00               0.625         0.302663        0.299304
# 2015-06-02 00:15:00               0.625         0.319876        0.299304
# 2015-06-02 00:30:00               0.625         0.369112        0.312312
# 2015-06-02 00:45:00               0.625         0.453503        0.359400
# 2015-06-02 01:00:00               0.625         0.565451        0.448766
#
#                      statusN_Rmax=3  statusN_Emin=3  statusN_Emax=3  \
# dt
# 2015-06-02 00:00:00        0.305214        0.438567        0.434921
# 2015-06-02 00:15:00        0.351232        0.438567        0.552682
# 2015-06-02 00:30:00        0.438567        0.438567        0.681281
# 2015-06-02 00:45:00        0.555569        0.795359        0.794030
# 2015-06-02 01:00:00        0.683338        0.795359        0.873256
#
#                      statusN_Esum=3  statusN_Emean=3
# dt
# 2015-06-02 00:00:00        0.148710         0.434921
# 2015-06-02 00:15:00        0.339906         0.493801
# 2015-06-02 00:30:00        0.575073         0.556295
# 2015-06-02 00:45:00        0.271498         0.794030
# 2015-06-02 01:00:00        0.572306         0.833643
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Adding Working / Peak Features

# %%
if WP:
    merged_dataset = addWorkingPeakFeatures(merged_dataset)
    print("Adding working / peak days")
# Out:
# Adding working / peak days

# %% [markdown]
# <br><br>
# ## Preparing Training dataset

# %% [markdown]
# ### Merge Original (and Rolling and Expanding)

# %%
# To-be Predicted variable 
Y = merged_dataset.statusN
Y = Y.fillna(0)

# %%
# Training Data
X = merged_dataset
X = X.drop(X.columns[[0]], axis=1)

# Splitting data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.67, shuffle=False)
X_train = np.array(X_train)
X_test = np.array(X_test)
Y_train = np.array(Y_train)
Y_test = np.array(Y_test)

# Data scaling
min_max_scaler = MinMaxScaler()
X_train = min_max_scaler.fit_transform(X_train)

#Print training and testing data
pd.concat([X, Y.to_frame()], axis=1).head()
# Out:
#                      month  year       day      hour       min  dayOfWeek  \
# dt
# 2015-06-02 00:00:00    0.0   0.0  0.033333  0.000000  0.000000   0.166667
# 2015-06-02 00:15:00    0.0   0.0  0.033333  0.000000  0.333333   0.166667
# 2015-06-02 00:30:00    0.0   0.0  0.033333  0.000000  0.666667   0.166667
# 2015-06-02 00:45:00    0.0   0.0  0.033333  0.000000  1.000000   0.166667
# 2015-06-02 01:00:00    0.0   0.0  0.033333  0.043478  0.000000   0.166667
#
#                      statusN_96  windspeedMiles  heatIndexC  dewPointC  \
# dt
# 2015-06-02 00:00:00    0.908264        0.178571    0.304348      0.625
# 2015-06-02 00:15:00    0.909505        0.178571    0.293478      0.625
# 2015-06-02 00:30:00    0.910818        0.178571    0.282609      0.625
# 2015-06-02 00:45:00    0.912204        0.178571    0.271739      0.625
# 2015-06-02 01:00:00    0.913664        0.178571    0.260870      0.625
#
#                        ...     statusN_Rmean=3  statusN_Rmin=3  \
# dt                     ...
# 2015-06-02 00:00:00    ...            0.302663        0.299304
# 2015-06-02 00:15:00    ...            0.319876        0.299304
# 2015-06-02 00:30:00    ...            0.369112        0.312312
# 2015-06-02 00:45:00    ...            0.453503        0.359400
# 2015-06-02 01:00:00    ...            0.565451        0.448766
#
#                      statusN_Rmax=3  statusN_Emin=3  statusN_Emax=3  \
# dt
# 2015-06-02 00:00:00        0.305214        0.438567        0.434921
# 2015-06-02 00:15:00        0.351232        0.438567        0.552682
# 2015-06-02 00:30:00        0.438567        0.438567        0.681281
# 2015-06-02 00:45:00        0.555569        0.795359        0.794030
# 2015-06-02 01:00:00        0.683338        0.795359        0.873256
#
#                      statusN_Esum=3  statusN_Emean=3  work_day  peak_hour  \
# dt
# 2015-06-02 00:00:00        0.148710         0.434921         1          0
# 2015-06-02 00:15:00        0.339906         0.493801         1          0
# 2015-06-02 00:30:00        0.575073         0.556295         1          0
# 2015-06-02 00:45:00        0.271498         0.794030         1          0
# 2015-06-02 01:00:00        0.572306         0.833643         1          0
#
#                       statusN
# dt
# 2015-06-02 00:00:00  0.438567
# 2015-06-02 00:15:00  0.555569
# 2015-06-02 00:30:00  0.683338
# 2015-06-02 00:45:00  0.795359
# 2015-06-02 01:00:00  0.874074
#
# [5 rows x 41 columns]

# %%
# Training
regressor = SupervisedDBNRegression(hidden_layers_structure=HIDDEN_LAYER_STRUCT,
                                    learning_rate_rbm=RBM_LEARNING_RATE,
                                    learning_rate=DBN_LEARNING_RATE,
                                    n_epochs_rbm=RBM_EPOCHS,
                                    n_iter_backprop=DBN_EPOCHS,
                                    batch_size=BATCH_SIZE,
                                    activation_function=ACTIVE_FUNC)
regressor.fit(X_train, Y_train)
# Out:
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 2.710930
# >> Epoch 2 finished 	RBM Reconstruction error 2.396035
# >> Epoch 3 finished 	RBM Reconstruction error 1.545673
# >> Epoch 4 finished 	RBM Reconstruction error 1.330669
# >> Epoch 5 finished 	RBM Reconstruction error 1.302862
# >> Epoch 1 finished 	RBM Reconstruction error 1.135949
# >> Epoch 2 finished 	RBM Reconstruction error 0.276294
# >> Epoch 3 finished 	RBM Reconstruction error 0.120462
# >> Epoch 4 finished 	RBM Reconstruction error 0.116715
# >> Epoch 5 finished 	RBM Reconstruction error 0.114490
# >> Epoch 1 finished 	RBM Reconstruction error 1.000243
# >> Epoch 2 finished 	RBM Reconstruction error 0.208913
# >> Epoch 3 finished 	RBM Reconstruction error 0.040975
# >> Epoch 4 finished 	RBM Reconstruction error 0.032902
# >> Epoch 5 finished 	RBM Reconstruction error 0.031471
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.006341
# >> Epoch 1 finished 	ANN training loss 0.005706
# >> Epoch 2 finished 	ANN training loss 0.005347
# >> Epoch 3 finished 	ANN training loss 0.005188
# >> Epoch 4 finished 	ANN training loss 0.004795
# >> Epoch 5 finished 	ANN training loss 0.004649
# >> Epoch 6 finished 	ANN training loss 0.004397
# >> Epoch 7 finished 	ANN training loss 0.004233
# >> Epoch 8 finished 	ANN training loss 0.004098
# >> Epoch 9 finished 	ANN training loss 0.003984
# >> Epoch 10 finished 	ANN training loss 0.003871
# >> Epoch 11 finished 	ANN training loss 0.003777
# >> Epoch 12 finished 	ANN training loss 0.003705
# >> Epoch 13 finished 	ANN training loss 0.003623
# >> Epoch 14 finished 	ANN training loss 0.003557
# >> Epoch 15 finished 	ANN training loss 0.003497
# >> Epoch 16 finished 	ANN training loss 0.003452
# >> Epoch 17 finished 	ANN training loss 0.003410
# >> Epoch 18 finished 	ANN training loss 0.003349
# >> Epoch 19 finished 	ANN training loss 0.003303
# >> Epoch 20 finished 	ANN training loss 0.003273
# >> Epoch 21 finished 	ANN training loss 0.003225
# >> Epoch 22 finished 	ANN training loss 0.003190
# >> Epoch 23 finished 	ANN training loss 0.003155
# >> Epoch 24 finished 	ANN training loss 0.003135
# >> Epoch 25 finished 	ANN training loss 0.003098
# >> Epoch 26 finished 	ANN training loss 0.003063
# >> Epoch 27 finished 	ANN training loss 0.003037
# >> Epoch 28 finished 	ANN training loss 0.003004
# >> Epoch 29 finished 	ANN training loss 0.002981
# >> Epoch 30 finished 	ANN training loss 0.002951
# >> Epoch 31 finished 	ANN training loss 0.002941
# >> Epoch 32 finished 	ANN training loss 0.002914
# >> Epoch 33 finished 	ANN training loss 0.002871
# >> Epoch 34 finished 	ANN training loss 0.002870
# >> Epoch 35 finished 	ANN training loss 0.002820
# >> Epoch 36 finished 	ANN training loss 0.002802
# >> Epoch 37 finished 	ANN training loss 0.002775
# >> Epoch 38 finished 	ANN training loss 0.002764
# >> Epoch 39 finished 	ANN training loss 0.002731
# >> Epoch 40 finished 	ANN training loss 0.002712
# >> Epoch 41 finished 	ANN training loss 0.002684
# >> Epoch 42 finished 	ANN training loss 0.002662
# >> Epoch 43 finished 	ANN training loss 0.002639
# >> Epoch 44 finished 	ANN training loss 0.002618
# >> Epoch 45 finished 	ANN training loss 0.002613
# >> Epoch 46 finished 	ANN training loss 0.002577
# >> Epoch 47 finished 	ANN training loss 0.002555
# >> Epoch 48 finished 	ANN training loss 0.002536
# >> Epoch 49 finished 	ANN training loss 0.002516
# >> Epoch 50 finished 	ANN training loss 0.002504
# >> Epoch 51 finished 	ANN training loss 0.002475
# >> Epoch 52 finished 	ANN training loss 0.002457
# >> Epoch 53 finished 	ANN training loss 0.002445
# >> Epoch 54 finished 	ANN training loss 0.002418
# >> Epoch 55 finished 	ANN training loss 0.002397
# >> Epoch 56 finished 	ANN training loss 0.002389
# >> Epoch 57 finished 	ANN training loss 0.002369
# >> Epoch 58 finished 	ANN training loss 0.002351
# >> Epoch 59 finished 	ANN training loss 0.002324
# >> Epoch 60 finished 	ANN training loss 0.002304
# >> Epoch 61 finished 	ANN training loss 0.002286
# >> Epoch 62 finished 	ANN training loss 0.002267
# >> Epoch 63 finished 	ANN training loss 0.002249
# >> Epoch 64 finished 	ANN training loss 0.002232
# >> Epoch 65 finished 	ANN training loss 0.002213
# >> Epoch 66 finished 	ANN training loss 0.002195
# >> Epoch 67 finished 	ANN training loss 0.002179
# >> Epoch 68 finished 	ANN training loss 0.002161
# >> Epoch 69 finished 	ANN training loss 0.002147
# >> Epoch 70 finished 	ANN training loss 0.002126
# >> Epoch 71 finished 	ANN training loss 0.002109
# >> Epoch 72 finished 	ANN training loss 0.002091
# >> Epoch 73 finished 	ANN training loss 0.002092
# >> Epoch 74 finished 	ANN training loss 0.002057
# >> Epoch 75 finished 	ANN training loss 0.002070
# >> Epoch 76 finished 	ANN training loss 0.002023
# >> Epoch 77 finished 	ANN training loss 0.002007
# >> Epoch 78 finished 	ANN training loss 0.002043
# >> Epoch 79 finished 	ANN training loss 0.001975
# >> Epoch 80 finished 	ANN training loss 0.001977
# >> Epoch 81 finished 	ANN training loss 0.001956
# >> Epoch 82 finished 	ANN training loss 0.001934
# >> Epoch 83 finished 	ANN training loss 0.001910
# >> Epoch 84 finished 	ANN training loss 0.001898
# >> Epoch 85 finished 	ANN training loss 0.001876
# >> Epoch 86 finished 	ANN training loss 0.001865
# >> Epoch 87 finished 	ANN training loss 0.001862
# >> Epoch 88 finished 	ANN training loss 0.001831
# >> Epoch 89 finished 	ANN training loss 0.001815
# >> Epoch 90 finished 	ANN training loss 0.001799
# >> Epoch 91 finished 	ANN training loss 0.001789
# >> Epoch 92 finished 	ANN training loss 0.001772
# >> Epoch 93 finished 	ANN training loss 0.001772
# >> Epoch 94 finished 	ANN training loss 0.001762
# >> Epoch 95 finished 	ANN training loss 0.001727
# >> Epoch 96 finished 	ANN training loss 0.001707
# >> Epoch 97 finished 	ANN training loss 0.001715
# >> Epoch 98 finished 	ANN training loss 0.001694
# >> Epoch 99 finished 	ANN training loss 0.001664
# >> Epoch 100 finished 	ANN training loss 0.001652
# >> Epoch 101 finished 	ANN training loss 0.001646
# >> Epoch 102 finished 	ANN training loss 0.001619
# >> Epoch 103 finished 	ANN training loss 0.001604
# >> Epoch 104 finished 	ANN training loss 0.001589
# >> Epoch 105 finished 	ANN training loss 0.001578
# >> Epoch 106 finished 	ANN training loss 0.001564
# >> Epoch 107 finished 	ANN training loss 0.001546
# >> Epoch 108 finished 	ANN training loss 0.001533
# >> Epoch 109 finished 	ANN training loss 0.001517
# >> Epoch 110 finished 	ANN training loss 0.001519
# >> Epoch 111 finished 	ANN training loss 0.001490
# >> Epoch 112 finished 	ANN training loss 0.001476
# >> Epoch 113 finished 	ANN training loss 0.001462
# >> Epoch 114 finished 	ANN training loss 0.001452
# >> Epoch 115 finished 	ANN training loss 0.001440
# >> Epoch 116 finished 	ANN training loss 0.001427
# >> Epoch 117 finished 	ANN training loss 0.001417
# >> Epoch 118 finished 	ANN training loss 0.001396
# >> Epoch 119 finished 	ANN training loss 0.001382
# >> Epoch 120 finished 	ANN training loss 0.001367
# >> Epoch 121 finished 	ANN training loss 0.001354
# >> Epoch 122 finished 	ANN training loss 0.001340
# >> Epoch 123 finished 	ANN training loss 0.001329
# >> Epoch 124 finished 	ANN training loss 0.001320
# >> Epoch 125 finished 	ANN training loss 0.001307
# >> Epoch 126 finished 	ANN training loss 0.001293
# >> Epoch 127 finished 	ANN training loss 0.001278
# >> Epoch 128 finished 	ANN training loss 0.001269
# >> Epoch 129 finished 	ANN training loss 0.001250
# >> Epoch 130 finished 	ANN training loss 0.001236
# >> Epoch 131 finished 	ANN training loss 0.001223
# >> Epoch 132 finished 	ANN training loss 0.001210
# >> Epoch 133 finished 	ANN training loss 0.001198
# >> Epoch 134 finished 	ANN training loss 0.001190
# >> Epoch 135 finished 	ANN training loss 0.001174
# >> Epoch 136 finished 	ANN training loss 0.001164
# >> Epoch 137 finished 	ANN training loss 0.001152
# >> Epoch 138 finished 	ANN training loss 0.001150
# >> Epoch 139 finished 	ANN training loss 0.001125
# >> Epoch 140 finished 	ANN training loss 0.001116
# >> Epoch 141 finished 	ANN training loss 0.001109
# >> Epoch 142 finished 	ANN training loss 0.001092
# >> Epoch 143 finished 	ANN training loss 0.001080
# >> Epoch 144 finished 	ANN training loss 0.001067
# >> Epoch 145 finished 	ANN training loss 0.001055
# >> Epoch 146 finished 	ANN training loss 0.001044
# >> Epoch 147 finished 	ANN training loss 0.001033
# >> Epoch 148 finished 	ANN training loss 0.001022
# >> Epoch 149 finished 	ANN training loss 0.001013
# [END] Fine tuning step
# SupervisedDBNRegression(batch_size=28, dropout_p=0, l2_regularization=1.0,
#             learning_rate=0.01, n_iter_backprop=150, verbose=True)

# %%
#To check RBM Loss Errors:
rbm_error = regressor.unsupervised_dbn.rbm_layers[0].rbm_loss_error
#To check DBN Loss Errors
dbn_error = regressor.dbn_loss_error

# %%
# Test
# X_test = min_max_scaler.transform(X_test)
# Y_pred = regressor.predict(X_test)

min_max_scaler = MinMaxScaler()
X_test = min_max_scaler.fit_transform(X_test)
Y_pred = regressor.predict(X_test)

r2score = r2_score(Y_test, Y_pred)
rmse = np.sqrt(mean_squared_error(Y_test, Y_pred))
mae = mean_absolute_error(Y_test, Y_pred)
print('Done.\nR-squared: %.3f\nRMSE: %.3f \nMAE: %.3f' % (r2score, rmse, mae))
# Out:
# Done.
# R-squared: 0.961
# RMSE: 0.063
# MAE: 0.042

# %%
# Save the model
regressor.save('models/ff_' + ROAD + '_' + YEAR + '.pkl')

# %% [markdown]
# ### Results and Analysis below

# %% [markdown]
# ##### Printing Predicted and Actual Results

# %%
startIndex = orig_weather.shape[0] - Y_pred.shape[0]
dt = orig_weather.index[startIndex:,]
temp = []
for i in range(len(Y_pred)):
    temp.append(Y_pred[i][0])
d = {'Predicted': temp, 'Actual': Y_test, 'dt':dt}

df = pd.DataFrame(data=d)
df.head()
# Out:
#      Actual  Predicted                  dt
# 0  0.932784   0.854902 2015-07-22 03:45:00
# 1  0.940946   0.863507 2015-07-22 04:00:00
# 2  0.937501   0.878152 2015-07-22 04:15:00
# 3  0.916327   0.844678 2015-07-22 04:30:00
# 4  0.870975   0.841722 2015-07-22 04:45:00

# %%
df.tail()
# Out:
#         Actual  Predicted                  dt
# 9772  0.307593   0.330329 2015-10-31 22:45:00
# 9773  0.289160   0.329993 2015-10-31 23:00:00
# 9774  0.284117   0.297908 2015-10-31 23:15:00
# 9775  0.304501   0.305816 2015-10-31 23:30:00
# 9776  0.360046   0.327758 2015-10-31 23:45:00

# %% [markdown]
# #### Visualize Actual vs Predicted

# %%
import matplotlib.pyplot as plt

# %%
line1 = df.Actual
line2 = df.Predicted

plt.grid()
plt.plot(line1, c='red', alpha=0.4)
plt.plot(line2, c='blue', alpha=0.4)
plt.xlabel("Date")
plt.ylabel("Traffic Speed")
plt.yticks([0, 0.5, 1.0])
plt.show()

# %%
#### Visualize trend of loss of RBM and DBN Training

import matplotlib.pyplot as plt

line1 = df.Actual
line2 = df.Predicted

plt.grid()
plt.plot(line1, c='red', alpha=0.4)
plt.plot(line2, c='blue', alpha=0.4)
plt.xlabel("Date")
plt.ylabel("Traffic Speed")
plt.yticks([0, 0.5, 1.0])
plt.show()

# %%
df.to_csv("output/ff_" + ROAD + "_" + YEAR + EXT, encoding='utf-8')
