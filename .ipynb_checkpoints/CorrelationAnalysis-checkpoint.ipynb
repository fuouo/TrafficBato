# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from pandas.plotting import autocorrelation_plot
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler

# %%
def normalize(data):
    y = pd.to_numeric(data)
    y = np.array(y.reshape(-1, 1))
    
    scaler = MinMaxScaler()
    y = scaler.fit_transform(y)
    y = y.reshape(1, -1)[0]
    return y

# %% [markdown]
# ## Importing Datasets

# %%
ROAD = "Taft Ave."
YEAR = "2015"
EXT = ".csv"

# %% [markdown]
# #### Traffic Dataset

# %%
TRAFFIC_WINDOWSIZE = 1
TRAFFIC_FILENAME = "mmda_" + ROAD + "_" + YEAR +  "_transformed"
traffic_raw_data = pd.read_csv("../../../datasets/mmda/2015/transformed/" + TRAFFIC_FILENAME + EXT, skipinitialspace=True)
traffic_raw_data = traffic_raw_data.fillna(0)
traffic_dataset = traffic_raw_data

cols_to_remove =  [1, 2]

traffic_dataset.drop(traffic_raw_data.columns[[cols_to_remove]], axis=1, inplace=True)
traffic_dataset.head()
# Out:
#                     dt    statusN    statusS
# 0  2015-01-01 00:00:00  15.583653  15.505402
# 1  2015-01-01 00:15:00  15.575252  15.505135
# 2  2015-01-01 00:30:00  15.567191  15.504873
# 3  2015-01-01 00:45:00  15.559462  15.504616
# 4  2015-01-01 01:00:00  15.552062  15.504365

# %% [markdown]
# #### Weather Dataset

# %%
WEATHER_WINDOWSIZE = 2
WEATHER_FILENAME = "wwo_" + YEAR 
weather_dataset = pd.read_csv("../../../datasets/wwo/all-features/" + WEATHER_FILENAME + EXT, skipinitialspace=True)
weather_dataset = weather_dataset.fillna(0)

cols_to_remove = [0]
cols_to_remove += [2, 3, 13, 15, 17, 18, 21] #Remove Fahr and Miles features
weather_dataset = weather_dataset.drop(weather_dataset.columns[[cols_to_remove]], axis=1)
weather_dataset.head()
# Out:
#     tempC  windspeedKmph  winddirDegree      cond  precipMM  humidity  \
# 0  0.2000       0.295455       0.152975  0.631579       0.0   0.84058
# 1  0.1875       0.295455       0.152266  0.631579       0.0   0.84058
# 2  0.1750       0.295455       0.151558  0.631579       0.0   0.84058
# 3  0.1625       0.295455       0.150850  0.631579       0.0   0.84058
# 4  0.1500       0.295455       0.150142  0.631579       0.0   0.84058
#
#    visibility  pressure  cloudcover  heatIndexC  dewPointC  windChillC  \
# 0         1.0  0.758621       0.330    0.206897   0.538462      0.2000
# 1         1.0  0.758621       0.325    0.206897   0.538462      0.1875
# 2         1.0  0.758621       0.320    0.206897   0.538462      0.1750
# 3         1.0  0.758621       0.315    0.206897   0.538462      0.1625
# 4         1.0  0.758621       0.310    0.206897   0.538462      0.1500
#
#    windGustKmph  feelsLikeC
# 0      0.236111    0.206897
# 1      0.239583    0.206897
# 2      0.243056    0.206897
# 3      0.246528    0.206897
# 4      0.250000    0.206897

# %%
merged_dataset = pd.merge(traffic_dataset, weather_dataset, left_index=True, right_index=True)
merged_dataset.head()
# Out:
#      statusN    statusS   tempC  windspeedKmph  winddirDegree      cond  \
# 0  15.583653  15.505402  0.2000       0.295455       0.152975  0.631579
# 1  15.575252  15.505135  0.1875       0.295455       0.152266  0.631579
# 2  15.567191  15.504873  0.1750       0.295455       0.151558  0.631579
# 3  15.559462  15.504616  0.1625       0.295455       0.150850  0.631579
# 4  15.552062  15.504365  0.1500       0.295455       0.150142  0.631579
#
#    precipMM  humidity  visibility  pressure  cloudcover  heatIndexC  \
# 0       0.0   0.84058         1.0  0.758621       0.330    0.206897
# 1       0.0   0.84058         1.0  0.758621       0.325    0.206897
# 2       0.0   0.84058         1.0  0.758621       0.320    0.206897
# 3       0.0   0.84058         1.0  0.758621       0.315    0.206897
# 4       0.0   0.84058         1.0  0.758621       0.310    0.206897
#
#    dewPointC  windChillC  windGustKmph  feelsLikeC
# 0   0.538462      0.2000      0.236111    0.206897
# 1   0.538462      0.1875      0.239583    0.206897
# 2   0.538462      0.1750      0.243056    0.206897
# 3   0.538462      0.1625      0.246528    0.206897
# 4   0.538462      0.1500      0.250000    0.206897

# %% [markdown]
# ### Visualize Datasets

# %% [markdown]
# #### Visualize Traffic

# %%
startMonth = 14496
endMonth = 29184

#96 rows in one day
#January 0 - 2976
#February - 2976 - 5665
#March - 5664 - 8640
#April - 8640 -  11520
#May - 11520 - 14496
#June - 14496 - 17376
#July - 17376 - 20352
#August - 20352 - 23330
#September = 23330 to 26209
#October - 26209 to 29184
#November - 29184 to 32064
#December - 32064 to 35040

td = traffic_dataset
td.statusN = normalize(traffic_dataset.statusN)
td.statusS = normalize(traffic_dataset.statusS)

plt.figure(figsize=(20, 4))
# for w in weather_dataset.columns:
#     plt.plot(td.iloc[startMonth:endMonth,:].dt, weather_dataset[w][startMonth-95:endMonth-95])

xaxis = range(9, 12)
# plt.plot(weather_dataset['precipMM'][startMonth:endMonth].rolling(96).mean())
plt.plot(td.iloc[startMonth:endMonth,:].statusS, alpha=0.2, c='b')
plt.plot(td.iloc[startMonth:endMonth,:].statusS.rolling(96).mean(), c='black')

plt.plot(weather_dataset.iloc[startMonth:endMonth,:].precipMM, alpha=0.2,c='r')
plt.plot(weather_dataset.iloc[startMonth:endMonth,:].precipMM.rolling(60).mean(), c='green')

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wd = weather_dataset.iloc[startMonth:endMonth,:].rolling(2880).mean()
d1 = td.iloc[startMonth:endMonth,:].rolling(2880).mean()
d2 = wd.rolling(672).mean()
df = pd.merge(d1, d2, left_index=True, right_index=True)
print("===============================\nWith Rolling Mean")
cor = df.corr(method='spearman')
print(cor.iloc[:, 0:2])
print()
print("Highly Correlated Features")
getAllHighCorr(cor, 0.1)


d1 = td
d2 = wd
df = pd.merge(d1, d2, left_index=True, right_index=True)
print("===============================\nWithout Rolling Mean")
cor = df.corr(method='spearman')
print(cor.iloc[:, 0:2])
print()
print("Highly Correlated Features")
getAllHighCorr(cor, 0.1)
# Out:
# ===============================
# With Rolling Mean
#                 statusN   statusS
# statusN        1.000000 -0.662335
# statusS       -0.662335  1.000000
# tempC          0.009394 -0.233156
# windspeedKmph  0.702029 -0.535947
# winddirDegree  0.689786 -0.553360
# cond          -0.412431  0.024961
# precipMM       0.426986 -0.420583
# humidity      -0.385555  0.428139
# visibility    -0.407632  0.494033
# pressure      -0.738908  0.680440
# cloudcover     0.715724 -0.523944
# heatIndexC    -0.241106 -0.003743
# dewPointC     -0.717916  0.569628
# windChillC     0.008849 -0.233033
# windGustKmph   0.684479 -0.518719
# feelsLikeC    -0.241106 -0.003743
#
# Highly Correlated Features
#                 statusS
# statusN       -0.662335
# statusS        1.000000
# tempC         -0.233156
# windspeedKmph -0.535947
# winddirDegree -0.553360
# precipMM      -0.420583
# humidity       0.428139
# visibility     0.494033
# pressure       0.680440
# cloudcover    -0.523944
# dewPointC      0.569628
# windChillC    -0.233033
# windGustKmph  -0.518719
#
#
#
#
#
#                   tempC
# statusS       -0.233156
# tempC          1.000000
# windspeedKmph -0.370046
# cond           0.732516
# precipMM      -0.458058
# humidity      -0.851847
# visibility     0.375686
# cloudcover    -0.368869
# heatIndexC     0.915724
# windChillC     0.999985
# windGustKmph  -0.390056
# feelsLikeC     0.915724
#
#
#
#
#
#                windspeedKmph
# statusN             0.702029
# statusS            -0.535947
# tempC              -0.370046
# windspeedKmph       1.000000
# winddirDegree       0.739630
# cond               -0.667957
# precipMM            0.735505
# visibility         -0.613400
# pressure           -0.872843
# cloudcover          0.908538
# heatIndexC         -0.549557
# dewPointC          -0.498149
# windChillC         -0.370969
# windGustKmph        0.987654
# feelsLikeC         -0.549557
#
#
#
#
#
#                winddirDegree
# statusN             0.689786
# statusS            -0.553360
# windspeedKmph       0.739630
# winddirDegree       1.000000
# cond               -0.203691
# precipMM            0.800649
# visibility         -0.761197
# pressure           -0.791355
# cloudcover          0.851770
# heatIndexC         -0.183394
# dewPointC          -0.116558
# windGustKmph        0.783987
# feelsLikeC         -0.183394
#
#
#
#
#
#                    cond
# statusN       -0.412431
# tempC          0.732516
# windspeedKmph -0.667957
# winddirDegree -0.203691
# cond           1.000000
# precipMM      -0.357733
# humidity      -0.383397
# visibility     0.215132
# pressure       0.324521
# cloudcover    -0.586222
# heatIndexC     0.858840
# dewPointC      0.474425
# windChillC     0.733246
# windGustKmph  -0.638054
# feelsLikeC     0.858840
#
#
#
#
#
#                precipMM
# statusN        0.426986
# statusS       -0.420583
# tempC         -0.458058
# windspeedKmph  0.735505
# winddirDegree  0.800649
# cond          -0.357733
# precipMM       1.000000
# humidity       0.359313
# visibility    -0.963317
# pressure      -0.623276
# cloudcover     0.846403
# heatIndexC    -0.481001
# windChillC    -0.458692
# windGustKmph   0.806262
# feelsLikeC    -0.481001
#
#
#
#
#
#               humidity
# statusN      -0.385555
# statusS       0.428139
# tempC        -0.851847
# cond         -0.383397
# precipMM      0.359313
# humidity      1.000000
# visibility   -0.294144
# pressure      0.292389
# heatIndexC   -0.648412
# dewPointC     0.409049
# windChillC   -0.851792
# windGustKmph  0.110045
# feelsLikeC   -0.648412
#
#
#
#
#
#                visibility
# statusN         -0.407632
# statusS          0.494033
# tempC            0.375686
# windspeedKmph   -0.613400
# winddirDegree   -0.761197
# cond             0.215132
# precipMM        -0.963317
# humidity        -0.294144
# visibility       1.000000
# pressure         0.564627
# cloudcover      -0.776772
# heatIndexC       0.402218
# windChillC       0.376021
# windGustKmph    -0.687908
# feelsLikeC       0.402218
#
#
#
#
#
#                pressure
# statusN       -0.738908
# statusS        0.680440
# windspeedKmph -0.872843
# winddirDegree -0.791355
# cond           0.324521
# precipMM      -0.623276
# humidity       0.292389
# visibility     0.564627
# pressure       1.000000
# cloudcover    -0.821299
# heatIndexC     0.184424
# dewPointC      0.486672
# windGustKmph  -0.851977
# feelsLikeC     0.184424
#
#
#
#
#
#                cloudcover
# statusN          0.715724
# statusS         -0.523944
# tempC           -0.368869
# windspeedKmph    0.908538
# winddirDegree    0.851770
# cond            -0.586222
# precipMM         0.846403
# visibility      -0.776772
# pressure        -0.821299
# cloudcover       1.000000
# heatIndexC      -0.547014
# dewPointC       -0.342110
# windChillC      -0.370052
# windGustKmph     0.935164
# feelsLikeC      -0.547014
#
#
#
#
#
#                heatIndexC
# statusN         -0.241106
# tempC            0.915724
# windspeedKmph   -0.549557
# winddirDegree   -0.183394
# cond             0.858840
# precipMM        -0.481001
# humidity        -0.648412
# visibility       0.402218
# pressure         0.184424
# cloudcover      -0.547014
# heatIndexC       1.000000
# dewPointC        0.298096
# windChillC       0.915959
# windGustKmph    -0.556549
# feelsLikeC       1.000000
#
#
#
#
#
#                dewPointC
# statusN        -0.717916
# statusS         0.569628
# windspeedKmph  -0.498149
# winddirDegree  -0.116558
# cond            0.474425
# humidity        0.409049
# pressure        0.486672
# cloudcover     -0.342110
# heatIndexC      0.298096
# dewPointC       1.000000
# windGustKmph   -0.416309
# feelsLikeC      0.298096
#
#
#
#
#
#                windChillC
# statusS         -0.233033
# tempC            0.999985
# windspeedKmph   -0.370969
# cond             0.733246
# precipMM        -0.458692
# humidity        -0.851792
# visibility       0.376021
# cloudcover      -0.370052
# heatIndexC       0.915959
# windChillC       1.000000
# windGustKmph    -0.391055
# feelsLikeC       0.915959
#
#
#
#
#
#                windGustKmph
# statusN            0.684479
# statusS           -0.518719
# tempC             -0.390056
# windspeedKmph      0.987654
# winddirDegree      0.783987
# cond              -0.638054
# precipMM           0.806262
# humidity           0.110045
# visibility        -0.687908
# pressure          -0.851977
# cloudcover         0.935164
# heatIndexC        -0.556549
# dewPointC         -0.416309
# windChillC        -0.391055
# windGustKmph       1.000000
# feelsLikeC        -0.556549
#
#
#
#
#
# ===============================
# Without Rolling Mean
#                 statusN   statusS
# statusN        1.000000  0.239763
# statusS        0.239763  1.000000
# tempC          0.061608 -0.040080
# windspeedKmph  0.146892 -0.085999
# winddirDegree  0.069537 -0.088131
# cond          -0.075737 -0.023886
# precipMM      -0.017971 -0.056402
# humidity      -0.185037  0.055134
# visibility     0.016942  0.060346
# pressure      -0.188308  0.115421
# cloudcover     0.084687 -0.075002
# heatIndexC    -0.026509 -0.029444
# dewPointC     -0.279809  0.027785
# windChillC     0.062159 -0.039765
# windGustKmph   0.122244 -0.078924
# feelsLikeC    -0.026509 -0.029444
#
# Highly Correlated Features
#            statusS
# statusN   0.239763
# statusS   1.000000
# pressure  0.115421
#
#
#
#
#
#                   tempC
# tempC          1.000000
# windspeedKmph -0.450544
# winddirDegree -0.103350
# cond           0.739517
# precipMM      -0.487095
# humidity      -0.872419
# visibility     0.404081
# cloudcover    -0.445863
# heatIndexC     0.928493
# windChillC     0.999991
# windGustKmph  -0.484155
# feelsLikeC     0.928493
#
#
#
#
#
#                windspeedKmph
# statusN             0.146892
# tempC              -0.450544
# windspeedKmph       1.000000
# winddirDegree       0.663992
# cond               -0.659388
# precipMM            0.728887
# humidity            0.177631
# visibility         -0.589619
# pressure           -0.797969
# cloudcover          0.872338
# heatIndexC         -0.603445
# dewPointC          -0.417007
# windChillC         -0.450827
# windGustKmph        0.988068
# feelsLikeC         -0.603445
#
#
#
#
#
#                winddirDegree
# tempC              -0.103350
# windspeedKmph       0.663992
# winddirDegree       1.000000
# cond               -0.151465
# precipMM            0.768483
# visibility         -0.737365
# pressure           -0.779254
# cloudcover          0.832806
# heatIndexC         -0.179505
# windChillC         -0.103689
# windGustKmph        0.699279
# feelsLikeC         -0.179505
#
#
#
#
#
#                    cond
# tempC          0.739517
# windspeedKmph -0.659388
# winddirDegree -0.151465
# cond           1.000000
# precipMM      -0.344729
# humidity      -0.419403
# visibility     0.194874
# pressure       0.236036
# cloudcover    -0.539380
# heatIndexC     0.854216
# dewPointC      0.404314
# windChillC     0.740238
# windGustKmph  -0.637817
# feelsLikeC     0.854216
#
#
#
#
#
#                precipMM
# tempC         -0.487095
# windspeedKmph  0.728887
# winddirDegree  0.768483
# cond          -0.344729
# precipMM       1.000000
# humidity       0.432107
# visibility    -0.959927
# pressure      -0.615696
# cloudcover     0.874536
# heatIndexC    -0.500380
# dewPointC      0.165698
# windChillC    -0.486942
# windGustKmph   0.798135
# feelsLikeC    -0.500380
#
#
#
#
#
#                humidity
# statusN       -0.185037
# tempC         -0.872419
# windspeedKmph  0.177631
# cond          -0.419403
# precipMM       0.432107
# humidity       1.000000
# visibility    -0.380987
# pressure       0.210610
# cloudcover     0.234215
# heatIndexC    -0.682410
# dewPointC      0.409811
# windChillC    -0.872225
# windGustKmph   0.240887
# feelsLikeC    -0.682410
#
#
#
#
#
#                visibility
# tempC            0.404081
# windspeedKmph   -0.589619
# winddirDegree   -0.737365
# cond             0.194874
# precipMM        -0.959927
# humidity        -0.380987
# visibility       1.000000
# pressure         0.563109
# cloudcover      -0.803818
# heatIndexC       0.408865
# dewPointC       -0.221739
# windChillC       0.403696
# windGustKmph    -0.663727
# feelsLikeC       0.408865
#
#
#
#
#
#                pressure
# statusN       -0.188308
# statusS        0.115421
# windspeedKmph -0.797969
# winddirDegree -0.779254
# cond           0.236036
# precipMM      -0.615696
# humidity       0.210610
# visibility     0.563109
# pressure       1.000000
# cloudcover    -0.781282
# heatIndexC     0.152499
# dewPointC      0.330500
# windGustKmph  -0.778702
# feelsLikeC     0.152499
#
#
#
#
#
#                cloudcover
# tempC           -0.445863
# windspeedKmph    0.872338
# winddirDegree    0.832806
# cond            -0.539380
# precipMM         0.874536
# humidity         0.234215
# visibility      -0.803818
# pressure        -0.781282
# cloudcover       1.000000
# heatIndexC      -0.581404
# dewPointC       -0.150638
# windChillC      -0.446100
# windGustKmph     0.903903
# feelsLikeC      -0.581404
#
#
#
#
#
#                heatIndexC
# tempC            0.928493
# windspeedKmph   -0.603445
# winddirDegree   -0.179505
# cond             0.854216
# precipMM        -0.500380
# humidity        -0.682410
# visibility       0.408865
# pressure         0.152499
# cloudcover      -0.581404
# heatIndexC       1.000000
# dewPointC        0.234552
# windChillC       0.928565
# windGustKmph    -0.623234
# feelsLikeC       1.000000
#
#
#
#
#
#                dewPointC
# statusN        -0.279809
# windspeedKmph  -0.417007
# cond            0.404314
# precipMM        0.165698
# humidity        0.409811
# visibility     -0.221739
# pressure        0.330500
# cloudcover     -0.150638
# heatIndexC      0.234552
# dewPointC       1.000000
# windGustKmph   -0.335039
# feelsLikeC      0.234552
#
#
#
#
#
#                windChillC
# tempC            0.999991
# windspeedKmph   -0.450827
# winddirDegree   -0.103689
# cond             0.740238
# precipMM        -0.486942
# humidity        -0.872225
# visibility       0.403696
# cloudcover      -0.446100
# heatIndexC       0.928565
# windChillC       1.000000
# windGustKmph    -0.484415
# feelsLikeC       0.928565
#
#
#
#
#
#                windGustKmph
# statusN            0.122244
# tempC             -0.484155
# windspeedKmph      0.988068
# winddirDegree      0.699279
# cond              -0.637817
# precipMM           0.798135
# humidity           0.240887
# visibility        -0.663727
# pressure          -0.778702
# cloudcover         0.903903
# heatIndexC        -0.623234
# dewPointC         -0.335039
# windChillC        -0.484415
# windGustKmph       1.000000
# feelsLikeC        -0.623234
# [statusN          1.000000
#  statusS          0.239763
#  windspeedKmph    0.146892
#  humidity        -0.185037
#  pressure        -0.188308
#  dewPointC       -0.279809
#  windGustKmph     0.122244
#  Name: statusN, dtype: float64,            statusS
#  statusN   0.239763
#  statusS   1.000000
#  pressure  0.115421,                   tempC
#  tempC          1.000000
#  windspeedKmph -0.450544
#  winddirDegree -0.103350
#  cond           0.739517
#  precipMM      -0.487095
#  humidity      -0.872419
#  visibility     0.404081
#  cloudcover    -0.445863
#  heatIndexC     0.928493
#  windChillC     0.999991
#  windGustKmph  -0.484155
#  feelsLikeC     0.928493,                windspeedKmph
#  statusN             0.146892
#  tempC              -0.450544
#  windspeedKmph       1.000000
#  winddirDegree       0.663992
#  cond               -0.659388
#  precipMM            0.728887
#  humidity            0.177631
#  visibility         -0.589619
#  pressure           -0.797969
#  cloudcover          0.872338
#  heatIndexC         -0.603445
#  dewPointC          -0.417007
#  windChillC         -0.450827
#  windGustKmph        0.988068
#  feelsLikeC         -0.603445,                winddirDegree
#  tempC              -0.103350
#  windspeedKmph       0.663992
#  winddirDegree       1.000000
#  cond               -0.151465
#  precipMM            0.768483
#  visibility         -0.737365
#  pressure           -0.779254
#  cloudcover          0.832806
#  heatIndexC         -0.179505
#  windChillC         -0.103689
#  windGustKmph        0.699279
#  feelsLikeC         -0.179505,                    cond
#  tempC          0.739517
#  windspeedKmph -0.659388
#  winddirDegree -0.151465
#  cond           1.000000
#  precipMM      -0.344729
#  humidity      -0.419403
#  visibility     0.194874
#  pressure       0.236036
#  cloudcover    -0.539380
#  heatIndexC     0.854216
#  dewPointC      0.404314
#  windChillC     0.740238
#  windGustKmph  -0.637817
#  feelsLikeC     0.854216,                precipMM
#  tempC         -0.487095
#  windspeedKmph  0.728887
#  winddirDegree  0.768483
#  cond          -0.344729
#  precipMM       1.000000
#  humidity       0.432107
#  visibility    -0.959927
#  pressure      -0.615696
#  cloudcover     0.874536
#  heatIndexC    -0.500380
#  dewPointC      0.165698
#  windChillC    -0.486942
#  windGustKmph   0.798135
#  feelsLikeC    -0.500380,                humidity
#  statusN       -0.185037
#  tempC         -0.872419
#  windspeedKmph  0.177631
#  cond          -0.419403
#  precipMM       0.432107
#  humidity       1.000000
#  visibility    -0.380987
#  pressure       0.210610
#  cloudcover     0.234215
#  heatIndexC    -0.682410
#  dewPointC      0.409811
#  windChillC    -0.872225
#  windGustKmph   0.240887
#  feelsLikeC    -0.682410,                visibility
#  tempC            0.404081
#  windspeedKmph   -0.589619
#  winddirDegree   -0.737365
#  cond             0.194874
#  precipMM        -0.959927
#  humidity        -0.380987
#  visibility       1.000000
#  pressure         0.563109
#  cloudcover      -0.803818
#  heatIndexC       0.408865
#  dewPointC       -0.221739
#  windChillC       0.403696
#  windGustKmph    -0.663727
#  feelsLikeC       0.408865,                pressure
#  statusN       -0.188308
#  statusS        0.115421
#  windspeedKmph -0.797969
#  winddirDegree -0.779254
#  cond           0.236036
#  precipMM      -0.615696
#  humidity       0.210610
#  visibility     0.563109
#  pressure       1.000000
#  cloudcover    -0.781282
#  heatIndexC     0.152499
#  dewPointC      0.330500
#  windGustKmph  -0.778702
#  feelsLikeC     0.152499,                cloudcover
#  tempC           -0.445863
#  windspeedKmph    0.872338
#  winddirDegree    0.832806
#  cond            -0.539380
#  precipMM         0.874536
#  humidity         0.234215
#  visibility      -0.803818
#  pressure        -0.781282
#  cloudcover       1.000000
#  heatIndexC      -0.581404
#  dewPointC       -0.150638
#  windChillC      -0.446100
#  windGustKmph     0.903903
#  feelsLikeC      -0.581404,                heatIndexC
#  tempC            0.928493
#  windspeedKmph   -0.603445
#  winddirDegree   -0.179505
#  cond             0.854216
#  precipMM        -0.500380
#  humidity        -0.682410
#  visibility       0.408865
#  pressure         0.152499
#  cloudcover      -0.581404
#  heatIndexC       1.000000
#  dewPointC        0.234552
#  windChillC       0.928565
#  windGustKmph    -0.623234
#  feelsLikeC       1.000000,                dewPointC
#  statusN        -0.279809
#  windspeedKmph  -0.417007
#  cond            0.404314
#  precipMM        0.165698
#  humidity        0.409811
#  visibility     -0.221739
#  pressure        0.330500
#  cloudcover     -0.150638
#  heatIndexC      0.234552
#  dewPointC       1.000000
#  windGustKmph   -0.335039
#  feelsLikeC      0.234552,                windChillC
#  tempC            0.999991
#  windspeedKmph   -0.450827
#  winddirDegree   -0.103689
#  cond             0.740238
#  precipMM        -0.486942
#  humidity        -0.872225
#  visibility       0.403696
#  cloudcover      -0.446100
#  heatIndexC       0.928565
#  windChillC       1.000000
#  windGustKmph    -0.484415
#  feelsLikeC       0.928565,                windGustKmph
#  statusN            0.122244
#  tempC             -0.484155
#  windspeedKmph      0.988068
#  winddirDegree      0.699279
#  cond              -0.637817
#  precipMM           0.798135
#  humidity           0.240887
#  visibility        -0.663727
#  pressure          -0.778702
#  cloudcover         0.903903
#  heatIndexC        -0.623234
#  dewPointC         -0.335039
#  windChillC        -0.484415
#  windGustKmph       1.000000
#  feelsLikeC        -0.623234, tempC            0.928493
#  windspeedKmph   -0.603445
#  winddirDegree   -0.179505
#  cond             0.854216
#  precipMM        -0.500380
#  humidity        -0.682410
#  visibility       0.408865
#  pressure         0.152499
#  cloudcover      -0.581404
#  heatIndexC       1.000000
#  dewPointC        0.234552
#  windChillC       0.928565
#  windGustKmph    -0.623234
#  feelsLikeC       1.000000
#  Name: feelsLikeC, dtype: float64]

# %% [markdown]
# ## Correlate

# %%
# correlate weather_dataset
tc = traffic_dataset.corr(method='spearman')
tc
# Out:
#          statusN  statusS
# statusN    1.000    0.204
# statusS    0.204    1.000

# %%
# correlate weather_dataset
wc = weather_dataset.iloc[14496:29184,:].corr(method='spearman')

#CorrelationPlot
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(wc, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(wc.columns),1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_yticklabels(wc.columns)
plt.show()

# %% [markdown]
# ### Analyzing the relationship of traffic to weather

# %%
#96 rows in one day
#January 0 - 2976
#February - 2976 - 5665
#March - 5664 - 8640
#April - 8640 -  11520
#May - 11520 - 14496
#June - 14496 - 17376
#July - 17376 - 20352
#August - 20352 - 23330
#September = 23330 to 26209
#October - 26209 to 29184
#November - 29184 to 32064
#December - 32064 to 35040

# %%
#Analyzing correlation of month of June to October (Rainy Season)
weather_lag = 0
startMonth = 5664
endMonth = 17376

traffic = traffic_dataset.iloc[startMonth:endMonth,:]
traffic.statusS = traffic.statusS.rolling(96).mean()
weather = weather_dataset.iloc[startMonth-weather_lag:endMonth-weather_lag,:]
merged_dataset = pd.merge(traffic, weather, left_index=True, right_index=True)
mdc_rainy = merged_dataset.corr(method='spearman')
mdc = mdc_rainy.iloc[0:2, :]
#CorrelationPlot
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(mdc, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(mdc.columns[0:2]),1)
ax.set_yticks(ticks)
ticks = np.arange(0,len(mdc.columns),1)
ax.set_xticks(ticks)
ax.set_yticklabels(mdc.columns[0:2])
plt.title("Rainy Season")

#Analyzing correlation of month of November to May (Dry Season)
weather_lag = 0
traffic = [traffic_dataset.iloc[0:14496,:], traffic_dataset.iloc[29184:35040,:]]# January to May, November to December
traffic = pd.concat(traffic)
traffic.statusS = traffic.statusS.rolling(96).mean()
weather = weather_dataset.iloc[startMonth-weather_lag:endMonth-weather_lag,:]
merged_dataset = pd.merge(traffic, weather, left_index=True, right_index=True)
mdc_dry = merged_dataset.corr(method='spearman')
mdc = mdc_dry.iloc[0:2, :]
#CorrelationPlot
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(mdc, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(mdc.columns[0:2]),1)
ax.set_yticks(ticks)
ticks = np.arange(0,len(mdc.columns),1)
ax.set_xticks(ticks)
ax.set_yticklabels(mdc.columns[0:2])
plt.title("Dry Season")

# Correlating one whole year
merged_dataset = pd.merge(traffic_dataset.iloc[:,:], weather_dataset.iloc[:,:], left_index=True, right_index=True)
merged_dataset.statusS =merged_dataset.statusS.rolling(96).mean()
mdc_year = merged_dataset.corr(method='spearman')
mdc = mdc_year.iloc[0:2, :]
#CorrelationPlot
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(mdc, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(mdc.columns[0:2]),1)
ax.set_yticks(ticks)
ticks = np.arange(0,len(mdc.columns),1)
ax.set_xticks(ticks)
ax.set_yticklabels(mdc.columns[0:2])
plt.title("Whole Year")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
def getAllHighCorr(dataset, limit):
    features = dataset.columns
    hc_features = []
    for w in range(0, len(features)):
        #print('Highly correlated with ' + w)
        col_name = features[w]
        col = dataset[col_name]
        temp = col[((col <= -limit) | (col >= limit))]
        hc_features.append(temp)
        #print(col[col>=0.5])
        #print('\n')
        
        
    for w in range(1, len(features)-1):
        hc_features[w] = hc_features[w].to_frame()
        print(hc_features[w])
        print('\n\n\n\n')
        
    return hc_features

# %%
# Get all Highly Correlated with Traffic of Dry Season
hc_features = getAllHighCorr(mdc_dry, 0.3)
# Out:
#          statusS
# statusS      1.0
#
#
#
#                   tempC
# tempC          1.000000
# winddirDegree  0.547846
# cond           0.607281
# humidity      -0.883915
# pressure      -0.442555
# heatIndexC     0.970027
# windChillC     0.999940
# feelsLikeC     0.970027
#
#
#
#                windspeedKmph
# windspeedKmph       1.000000
# humidity           -0.385829
# dewPointC          -0.442158
# windGustKmph        0.976123
#
#
#
#                winddirDegree
# tempC               0.547846
# winddirDegree       1.000000
# precipMM            0.437413
# humidity           -0.314068
# pressure           -0.730283
# heatIndexC          0.598544
# dewPointC           0.458790
# windChillC          0.547600
# feelsLikeC          0.598544
#
#
#
#                 cond
# tempC       0.607281
# cond        1.000000
# humidity   -0.624534
# heatIndexC  0.594428
# windChillC  0.607423
# feelsLikeC  0.594427
#
#
#
#                precipMM
# winddirDegree  0.437413
# precipMM       1.000000
# visibility    -0.586355
# pressure      -0.429379
# cloudcover     0.412552
# heatIndexC     0.305105
# dewPointC      0.405732
# feelsLikeC     0.305105
#
#
#
#                humidity
# tempC         -0.883915
# windspeedKmph -0.385829
# winddirDegree -0.314068
# cond          -0.624534
# humidity       1.000000
# heatIndexC    -0.790839
# windChillC    -0.883824
# feelsLikeC    -0.790836
#
#
#
#             visibility
# precipMM     -0.586355
# visibility    1.000000
#
#
#
#                pressure
# tempC         -0.442555
# winddirDegree -0.730283
# precipMM      -0.429379
# pressure       1.000000
# heatIndexC    -0.523943
# dewPointC     -0.556035
# windChillC    -0.442602
# feelsLikeC    -0.523946
#
#
#
#             cloudcover
# precipMM      0.412552
# cloudcover    1.000000
#
#
#
#                heatIndexC
# tempC            0.970027
# winddirDegree    0.598544
# cond             0.594428
# precipMM         0.305105
# humidity        -0.790839
# pressure        -0.523943
# heatIndexC       1.000000
# windChillC       0.970102
# feelsLikeC       1.000000
#
#
#
#                dewPointC
# windspeedKmph  -0.442158
# winddirDegree   0.458790
# precipMM        0.405732
# pressure       -0.556035
# dewPointC       1.000000
# windGustKmph   -0.455841
#
#
#
#                windChillC
# tempC            0.999940
# winddirDegree    0.547600
# cond             0.607423
# humidity        -0.883824
# pressure        -0.442602
# heatIndexC       0.970102
# windChillC       1.000000
# feelsLikeC       0.970102
#
#
#
#                windGustKmph
# windspeedKmph      0.976123
# dewPointC         -0.455841
# windGustKmph       1.000000

# %%
# Get all Highly Correlated with Traffic of Wet Season
hc_features = getAllHighCorr(mdc_rainy, 0.5)
# Out:
#          statusS
# statusS      1.0
#
#
#
#                tempC
# tempC       1.000000
# cond        0.588397
# humidity   -0.877399
# heatIndexC  0.965355
# windChillC  0.999956
# feelsLikeC  0.965355
#
#
#
#                windspeedKmph
# windspeedKmph       1.000000
# windGustKmph        0.973999
#
#
#
#                winddirDegree
# winddirDegree       1.000000
# pressure           -0.652044
# heatIndexC          0.530420
# feelsLikeC          0.530420
#
#
#
#                 cond
# tempC       0.588397
# cond        1.000000
# humidity   -0.589033
# heatIndexC  0.580492
# windChillC  0.588518
# feelsLikeC  0.580492
#
#
#
#             precipMM
# precipMM    1.000000
# visibility -0.647883
#
#
#
#             humidity
# tempC      -0.877399
# cond       -0.589033
# humidity    1.000000
# heatIndexC -0.775122
# windChillC -0.877335
# feelsLikeC -0.775120
#
#
#
#             visibility
# precipMM     -0.647883
# visibility    1.000000
#
#
#
#                pressure
# winddirDegree -0.652044
# pressure       1.000000
# heatIndexC    -0.501407
# dewPointC     -0.616530
# feelsLikeC    -0.501409
#
#
#
#             cloudcover
# cloudcover         1.0
#
#
#
#                heatIndexC
# tempC            0.965355
# winddirDegree    0.530420
# cond             0.580492
# humidity        -0.775122
# pressure        -0.501407
# heatIndexC       1.000000
# windChillC       0.965405
# feelsLikeC       1.000000
#
#
#
#            dewPointC
# pressure    -0.61653
# dewPointC    1.00000
#
#
#
#             windChillC
# tempC         0.999956
# cond          0.588518
# humidity     -0.877335
# heatIndexC    0.965405
# windChillC    1.000000
# feelsLikeC    0.965405
#
#
#
#                windGustKmph
# windspeedKmph      0.973999
# windGustKmph       1.000000

# %%
# Get all Highly Correlated with Traffic of the whole year
hc_features = getAllHighCorr(mdc_year, 0.1)
# Out:
#                 statusS
# statusN        0.204000
# statusS        1.000000
# tempC         -0.331357
# windspeedKmph -0.155130
# winddirDegree -0.172971
# cond          -0.139468
# precipMM      -0.102356
# humidity       0.312691
# heatIndexC    -0.295486
# windChillC    -0.331377
# windGustKmph  -0.123451
# feelsLikeC    -0.295486
#
#
#
#                   tempC
# statusS       -0.331357
# tempC          1.000000
# winddirDegree  0.386547
# cond           0.512631
# precipMM       0.126571
# humidity      -0.813179
# pressure      -0.320333
# cloudcover    -0.125661
# heatIndexC     0.966170
# dewPointC      0.311011
# windChillC     0.999923
# feelsLikeC     0.966172
#
#
#
#                windspeedKmph
# statusS            -0.155130
# windspeedKmph       1.000000
# humidity           -0.226920
# pressure            0.106337
# dewPointC          -0.332497
# windGustKmph        0.966191
#
#
#
#                winddirDegree
# statusS            -0.172971
# tempC               0.386547
# winddirDegree       1.000000
# cond                0.152191
# precipMM            0.508074
# visibility         -0.362021
# pressure           -0.703438
# cloudcover          0.223903
# heatIndexC          0.463647
# dewPointC           0.538730
# windChillC          0.386473
# feelsLikeC          0.463645
#
#
#
#                    cond
# statusS       -0.139468
# tempC          0.512631
# winddirDegree  0.152191
# cond           1.000000
# humidity      -0.474393
# pressure      -0.129126
# heatIndexC     0.495752
# windChillC     0.512729
# feelsLikeC     0.495758
#
#
#
#                precipMM
# statusS       -0.102356
# tempC          0.126571
# winddirDegree  0.508074
# precipMM       1.000000
# humidity       0.180657
# visibility    -0.736799
# pressure      -0.559365
# cloudcover     0.535621
# heatIndexC     0.227515
# dewPointC      0.522274
# windChillC     0.126670
# windGustKmph   0.114216
# feelsLikeC     0.227527
#
#
#
#                humidity
# statusS        0.312691
# tempC         -0.813179
# windspeedKmph -0.226920
# cond          -0.474393
# precipMM       0.180657
# humidity       1.000000
# visibility    -0.236898
# cloudcover     0.260237
# heatIndexC    -0.688936
# dewPointC      0.212013
# windChillC    -0.813280
# feelsLikeC    -0.688937
#
#
#
#                visibility
# winddirDegree   -0.362021
# precipMM        -0.736799
# humidity        -0.236898
# visibility       1.000000
# pressure         0.420753
# cloudcover      -0.419713
# heatIndexC      -0.110857
# dewPointC       -0.406094
# windGustKmph    -0.153452
# feelsLikeC      -0.110835
#
#
#
#                pressure
# tempC         -0.320333
# windspeedKmph  0.106337
# winddirDegree -0.703438
# cond          -0.129126
# precipMM      -0.559365
# visibility     0.420753
# pressure       1.000000
# cloudcover    -0.312812
# heatIndexC    -0.436671
# dewPointC     -0.643872
# windChillC    -0.320241
# feelsLikeC    -0.436662
#
#
#
#                cloudcover
# tempC           -0.125661
# winddirDegree    0.223903
# precipMM         0.535621
# humidity         0.260237
# visibility      -0.419713
# pressure        -0.312812
# cloudcover       1.000000
# dewPointC        0.230296
# windChillC      -0.125309
# windGustKmph     0.124907
#
#
#
#                heatIndexC
# statusS         -0.295486
# tempC            0.966170
# winddirDegree    0.463647
# cond             0.495752
# precipMM         0.227515
# humidity        -0.688936
# visibility      -0.110857
# pressure        -0.436671
# heatIndexC       1.000000
# dewPointC        0.502756
# windChillC       0.966147
# windGustKmph    -0.158216
# feelsLikeC       0.999999
#
#
#
#                dewPointC
# tempC           0.311011
# windspeedKmph  -0.332497
# winddirDegree   0.538730
# precipMM        0.522274
# humidity        0.212013
# visibility     -0.406094
# pressure       -0.643872
# cloudcover      0.230296
# heatIndexC      0.502756
# dewPointC       1.000000
# windChillC      0.310955
# windGustKmph   -0.329096
# feelsLikeC      0.502755
#
#
#
#                windChillC
# statusS         -0.331377
# tempC            0.999923
# winddirDegree    0.386473
# cond             0.512729
# precipMM         0.126670
# humidity        -0.813280
# pressure        -0.320241
# cloudcover      -0.125309
# heatIndexC       0.966147
# dewPointC        0.310955
# windChillC       1.000000
# feelsLikeC       0.966149
#
#
#
#                windGustKmph
# statusS           -0.123451
# windspeedKmph      0.966191
# precipMM           0.114216
# visibility        -0.153452
# cloudcover         0.124907
# heatIndexC        -0.158216
# dewPointC         -0.329096
# windGustKmph       1.000000
# feelsLikeC        -0.158213

# %% [markdown]
# ### Auto Correlation
# <b>I have no idea kung tama ginagawa ko :D</b>

# %%
traffic_dataset.iloc[0].autocorr(lag=100)
# Out:
# nan

# %%
#Auto Correlation of statusS
plt.figure(figsize=(10, 6))
#plt.acorr(traffic_dataset.iloc[23330:24002,:].statusS, maxlags=97)
plt.acorr(traffic_dataset.iloc[23330:24002,:].statusN, maxlags=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
autocorrelation_plot(traffic_dataset.iloc[23330:24002,:].statusS);
plt.show()

# %% [markdown]
# ### Miscellaneous Visualizations

# %%
traffic_dataset.iloc[23330:24002,:].statusS.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)
weather_dataset.iloc[23330:24002,:].tempC.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
plt.show()

# %%
traffic_dataset.iloc[20352:26209,:].statusS.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)

plt.show()

# %%
#Weekly
statusS = traffic_dataset.iloc[20352:26209,:].statusS
plt.figure(figsize=(10, 6))
plt.plot(traffic_dataset.iloc[20352:26209,:].dt, statusS.rolling(96).mean())
plt.show()

# %% [markdown]
# ### Export Correlated as CSV

# %%
merged_dataset.corr().to_csv("stats/cross-correlation7_" + ROAD + "_" + YEAR + EXT, encoding='utf-8')

# %%
merged_dataset.to_csv("stats/merged_dataset_" + ROAD + "_" + YEAR + EXT, encoding='utf-8')
